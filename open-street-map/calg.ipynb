# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import xml.etree.ElementTree as ET  # Use cElementTree or lxml if too slow

OSM_FILE = "calgary_canada.osm"  # Replace this with your osm file
SAMPLE_FILE = "calg.osm"

k = 10 # Parameter: take every k-th top level element

def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')

# %% [markdown]
# 使用迭代解析处理地图文件，找出有什么样的标记及其个数。

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import xml.etree.cElementTree as ET
import pprint

def count_tags(filename):
        
        elem_dict={}
        for _, elem in ET.iterparse(filename,events=("start",)):
            if elem.tag in elem_dict:
                elem_dict[elem.tag]+=1
            else:
                elem_dict[elem.tag]=1
        return elem_dict


if __name__ == "__main__":
    tags = count_tags('calgary_canada.osm')
    print (tags)
# Out:
# {'node': 904169, 'nd': 1095426, 'bounds': 1, 'member': 41473, 'tag': 518065, 'osm': 1, 'way': 122435, 'relation': 4845}

# %%
import xml.etree.ElementTree as ET
import pprint
#OSM_FILE = "calgary_canada.osm"  # Replace this with your osm file
SAMPLE_FILE = "calg.osm"
filename=SAMPLE_FILE     
with open (filename,"r") as f:
    phone= set()
    for event, elem in ET.iterparse(filename, events=("start",)):

        if elem.tag == "way" or elem.tag=="node":
            for tag in elem.iter("tag"):
                if tag.attrib['k']=='phone':
                    phone=tag.attrib['v']
                    print phone
# Out:
# +1.4032756577
# +1 403 299 2600
# 403 228 5553
# 403-244-2333
# +1-403-276-3313
# +1-403-457-6011
# +1-403-244-7676
# +1-403-280-3505
# +1 403 476 1308
# +1-403-263-0766
# (403) 278-0492
# +1-403-253-9200
# +1-403-777-5105
# +1-403-777-5140
# +1-403-777-5110
# +1-800-293-3717
# +1-403-299-4329
# +1-403-241-7053
# +1-403-239-8177
# +1 403 228 3668
# (403) 467-6719
# +1-403-276-8518
# +1-403-277-2666
# +1-403-444-4444
# +14039365855
# 1-855-800-0742
# +1-403-234-1840
# 403-276-6892
# +1 403 984 4143
# +1 403-663-8777
# +1 403 253 3174
# 403-203-1789
# 14039100321
# 403-266-7062
# +14039322154
# +1-403-201-4300
# +1-403-288-3333
# +1-403-289-9412
# +1-403-454-2738
# 1-403-460-0606
# +1-403-453-0828
# +1-403-931-6007
# +1-403-454-6101
# +1-587-351-9729
# +1-403-253-1555
# +1-403-252-2363
# +1-403-253-7588
# +1 (403) 264-7808
# +1-403-258-1827
# +1-403-870-8780
# +1-403-475-2676
# (403) 282-3588
# +1-403-454-8778
# +1-403-532-0085
# +1-403-720-6989
# +1-403-249-0858
# +1-403-719-8145
# +1-403-719-6899
# +1-403-271-7755
# +1-403-217-5337
# +1(403) 606-2158
# +1-403-247-4181
# (403) 282-0555
# +1-403-262-9360
# 587-352-7307
# +1-403-945-2337
# +1-403-256-7760
# +1-403-246-6404
# +1-403-300-1003
# +1-403-299-4331
# +1 403-777-7670
# +1 403-288-4461
# 403.685.6801
# 403 250-1133
# +1-
# +1-403-299-4334
# +1 403-777-6300
# +1 403-289-2581
# 403-225-1150
# (403)948-4188
# +1-403-932-2998
# +1 403-777-6720
# +1 403 265 8777
# +1 403-271-6116
# (403)932-6355
# +1 (403) 514-0099
# +1-403-299-4332
# +1 403-777-8330
# +1- 403-219-2475
# 403.768.2600
# +1 403-777-8310
# +1-403-297-1111
# 1 403 949 4008
# +1-403-276-3173
# +1 403-777-8063
# +1 403.272.9831
# +1 403-243-7211
# +1 403 205 4455
# +1403 777 7780
# +1 403 777 7680
# +1-403-777-7060
# +1 403-282-2234
# +1 403-221-3682
# +1 403-500-2091
# +1 403-500-2082
# +1 403-500-2120
# +1 403-777-8110
# +1 403-246-1231
# +1 403-777-7890
# +1-403-777-8070
# +1-403-777-8420
# +1-403-777-6970
# +1 403-932-9811
# +1-403-243-2244
# +1-403-500-2031
# +1-403-777-6760
# +1-403-500-2012
# +1-403-640-3555
# +1-403-936-3133

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import xml.etree.cElementTree as ET
import pprint
import re



lower = re.compile(r'^([a-z]|_)*$')   #表示仅包含小写字母且有效的标记
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')   #表示名称中有冒号的其他有效标记
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    if element.tag == "tag":
        # YOUR CODE HERE
        flag=0
        if re.search(lower,element.attrib["k"]):
            keys["lower"]+=1
            flag=1
        
        if re.search(lower_colon,element.attrib["k"]):
            keys["lower_colon"]+=1
            flag=1
            
        if re.search(problemchars,element.attrib["k"]):
            keys["problemchars"]+=1
            flag=1
        
        if flag==0:
            keys["other"]+=1
        
    return keys



def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys



#def test():
    # You can use another testfile 'map.osm' to look at your solution
    # Note that the assertion below will be incorrect then.
    # Note as well that the test function here is only used in the Test Run;
    # when you submit, your code will be checked against a different dataset.
    #keys = process_map('sample.osm')
    #pprint.pprint(keys)
    #assert keys == {'lower': 35770, 'lower_colon': 2934, 'other': 133, 'problemchars': 1}


if __name__ == "__main__":
    keys = process_map('calgary_canada.osm')
    
    print keys
# Out:
# {'problemchars': 1, 'lower': 430490, 'other': 11577, 'lower_colon': 75997}

# %% [markdown]
# 整理街道名称

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

OSMFILE = "calgary_canada.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons","Northeast","Northwest","Southeast",
            "Southwest","North","West","Highway","Way","W","N","E","S"]


# UPDATE THIS VARIABLE
mapping = { 
            "St.":"Street",
            "SE":"Southeast",
            "SW":"Southwest",
            "S.W.":"Southwest",
            "NE":"Northeast",
            "N.E.":"Northeast",
            "NW":"Northwest",
            "N.W":"Northwest",
            "N.W.":"Northwest",
            "Blvd":"Boulevard"
            
            
            }


def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types


def update_name(name, mapping):
    
    for word in mapping:
        if name.endswith(word):
            return name.replace(word,mapping[word])

    return name



if __name__ == '__main__':
    st_types = audit(OSMFILE)
    pprint.pprint(dict(st_types))
    for st_type, ways in st_types.iteritems():
        for name in ways:
            better_name = update_name(name, mapping)
            print name, "=>", better_name
# Out:
# {'1': set(['Edmonton Trail NE #1', 'Highway 1']),
#  '105': set(['29 Street SE #105']),
#  '108': set(['2 Ave NE #108']),
#  '12': set(['4 Street SW #12']),
#  '200': set(['West Creek Court 200']),
#  '201': set(['Fairmount Dr SE #201']),
#  '204A': set(['Township Road  204A']),
#  '205A': set(['Township Road  205A']),
#  '21': set(['21']),
#  '210': set(['3rd St SW Suite 210', 'Township Road  210']),
#  '210A': set(['Township Road  210A']),
#  '210B': set(['Township Road  210B']),
#  '224': set(['Township Road 224']),
#  '22X': set(['Highway 22X']),
#  '230': set(['12 St NE #230']),
#  '232': set(['Township Road  232', 'Township Road 232']),
#  '234': set(['Township Road  234']),
#  '243': set(['Township Road 243']),
#  '254A': set(['Twp Rd 254A']),
#  '261': set(['Township Road 261']),
#  '262A': set(['Township Road 262A']),
#  '293': set(['Range Road 293']),
#  '5': set(['1a St SW # 5']),
#  '50A': set(['Range Road  50A']),
#  '51': set(['Range Road  51']),
#  '51A': set(['Range Road  51A', 'Range Road 51A']),
#  '52': set(['Range Road  52', 'Range Road 52']),
#  '52A': set(['Range Road  52A']),
#  '66': set(['400123 Highway 66']),
#  'A': set(['East Lake Blvd NE #A']),
#  'AB': set(['32nd Street, Okotoks, AB']),
#  'Alberta': set(['Veterans Blvd., Airdrie, Alberta']),
#  'Ave': set(['27 Ave', 'River Ave']),
#  'Bay': set(['Lake Twintree Bay', 'Mount View Bay']),
#  'Blvd': set(['Drake Landing Blvd', 'Vetrans Blvd']),
#  'Blvd.': set(['Vetrans Blvd.']),
#  'Circle': set(['Hidden Ranch Circle']),
#  'Close': set(['Auburn Sound Close',
#                'Coyote Close',
#                'Redwood Meadows Close',
#                'Wild Rose Close',
#                'Wolf Close']),
#  'Common': set(['Crossiron Common', 'Jumping Pound Common', 'Sunset Common']),
#  'Cres': set(['Bracewood Cres']),
#  'Crescent': set(['Manyhorses Crescent',
#                   'Squirrel Crescent',
#                   'Sunrise Crescent',
#                   'Westmount Crescent',
#                   'White Crescent',
#                   'Wolf Crescent']),
#  'Dr': set(['MacLaurin Dr']),
#  'East': set(['2nd Avenue East',
#               '32nd Street East',
#               'MacLeod Trail South East']),
#  'Estates': set(['Lakeview Estates', 'Mount View Estates']),
#  'Gate': set(['Fireside Gate', 'Manyhorses Gate', 'Sandstone Gate']),
#  'Hollow': set(['Sleepy Hollow']),
#  'Landing': set(['Country Hills Landing']),
#  'Mews': set(['Eversyde Mews']),
#  'N.E.': set(['14th St. N.E.', '38th Avenue N.E.', '6th Street N.E.']),
#  'N.W': set(['Symons Valley Rd N.W']),
#  'N.W.': set(['Symons Valley Road N.W.']),
#  'NE': set(['#1, 666 Goddard Ave. NE',
#             '#5 - 2816 21 St NE',
#             '1 Ave NE',
#             '1 Avenue NE',
#             '1 Street NE',
#             '11 Street NE',
#             '116th St NE',
#             '11A Street NE',
#             '12 Street NE',
#             '13 Avenue NE',
#             '14 Avenue NE',
#             '14 Street NE',
#             '16 Avenue NE',
#             '16 Street NE',
#             '17 Avenue NE',
#             '17A Street NE',
#             '18 Avenue NE',
#             '19 Street NE',
#             '2 Avenue NE',
#             '2 Street NE',
#             '20 Avenue NE',
#             '21 Street NE',
#             '23 Avenue NE',
#             '23 Street NE',
#             '24 Avenue NE',
#             '24Avenue NE',
#             '24th Street NE',
#             '25 Street NE',
#             '2555-32nd Street NE',
#             '25th Street NE',
#             '26 Avenue NE',
#             '26 Street NE',
#             '27 Avenue NE',
#             '27 Street NE',
#             '27th Ave NE',
#             '29 Avenue NE',
#             '30 Avenue NE',
#             '32 Avenue NE',
#             '32 Street NE',
#             '33 Street NE',
#             '34 Avenue NE',
#             '34 Street NE',
#             '35 Avenue NE',
#             '35 Street NE',
#             '36 Street NE',
#             '39 Avenue NE',
#             '3A Street NE',
#             '4 Avenue NE',
#             '4 St NE',
#             '4 Street NE',
#             '40 Street NE',
#             '41 Avenue NE',
#             '42 Avenue NE',
#             '42 Street NE',
#             '43 Avenue NE',
#             '44 Avenue NE',
#             '5 Avenue NE',
#             '50 Street NE',
#             '52 Street NE',
#             '53 Avenue NE',
#             '54 Avenue NE',
#             '55 Avenue NE',
#             '56 Street NE',
#             '57 Avenue NE',
#             '5th Avenue NE',
#             '6 Street NE',
#             '60 Street NE',
#             '61 Street NE',
#             '63 Avenue NE',
#             '64 Ave. NE',
#             '64 Avenue NE',
#             '64th Ave NE',
#             '68 Street NE',
#             '6A St NE',
#             '6A Street NE',
#             '72 Avenue NE',
#             '78 Avenue NE',
#             '7A Street NE',
#             '8 Street NE',
#             '80 Avenue NE',
#             '9 Avenue NE',
#             'Abbeydale Drive NE',
#             'Abbotsford Drive NE',
#             'Abergale Drive NE',
#             'Aerial Place NE',
#             'Aero Drive NE',
#             'Aero Way NE',
#             'Airport Rd. NE',
#             'Airport Road NE',
#             'Aviation Park NE',
#             'Beddington Boulevard NE',
#             'California Boulevard NE',
#             'Castlebrook Drive NE',
#             'Castleridge Boulevard NE',
#             'Castleridge Drive NE',
#             'Catalina Boulevard NE',
#             'Centre Avenue NE',
#             'Centre Street NE',
#             'Coral Springs Boulevard NE',
#             'Country Village Cove NE',
#             'Country Village Link NE',
#             'Country Village Road NE',
#             'Country Village Way NE',
#             'Covehaven Gardens NE',
#             'Coventry Hills Way NE',
#             'Covepark Square NE',
#             'Covewood Park NE',
#             'Covewood Place NE',
#             'E Lake Cir NE',
#             'East Lake Boulevard NE',
#             'East Lake Crescent NE',
#             'Edmonton Trail NE',
#             'Falconride Boulevard NE',
#             'Falconridge Boulevard NE',
#             'Falconridge Drive NE',
#             'Falsbridge Drive NE',
#             'Falshire Drive NE',
#             'Freeport Crescent NE',
#             'Gateway Drive NE',
#             'Goddard Avenue NE',
#             'Harvest Creek Close NE',
#             'Harvest Gold Manor NE',
#             'Harvest Hills Blvd. NE',
#             'Harvest Hills Drive NE',
#             'Harvest Lake Drive NE',
#             'Harvest Oak Crescent NE',
#             'Hopewell Pl NE',
#             'Hopewell Way NE',
#             'Huntbourne Way NE',
#             'Hunterhorn Road NE',
#             'Huntford Hill NE',
#             'Huntford Way NE',
#             'Huntridge Hill NE',
#             'Madigan Drive NE',
#             'Marbank Drive NE',
#             'Marcombe Road NE',
#             'Marlborough Drive NE',
#             'Marlborough Way NE',
#             'Martin Crossing Place NE',
#             'Martindale Boulevard NE',
#             'Maryvale Drive NE',
#             'Mayland Drive NE',
#             'McCall Way NE',
#             'McDougall Court NE',
#             'McDougall Road NE',
#             'McKnight Boulevard NE',
#             'McPherson Road NE',
#             'Memorial Dr. NE',
#             'Meredith Rd NE',
#             'Meredith Road NE',
#             'Meridian Road NE',
#             'Moncton Road NE',
#             'Moraine Road NE',
#             'Pegasus Road NE',
#             'Pinehill Road NE',
#             'Pinetree Bay NE',
#             'Pinetree Crescent NE',
#             'Pinetree Road NE',
#             'Radford Road NE',
#             'Radnor Avenue NE',
#             'Rundlefield Close NE',
#             'Rundlefield Crescent NE',
#             'Rundlefield Road NE',
#             'Rundlehill Drive NE',
#             'Rundlehorn Drive NE',
#             'Rundlewood Drive NE',
#             'Russett Road NE',
#             'Saddlecrest Boulevard NE',
#             'Saddlecrest Way NE',
#             'Saddlehorn Drive NE',
#             'Saddlelake Way NE',
#             'Saddletowne Circle NE',
#             'Saddletree Close NE',
#             'Skyline Way NE',
#             'Skyview Ranch Road NE',
#             'Skyview Ranch Rroad NE',
#             'Skyview Ranch Street NE',
#             'Skyview Springs Cove NE',
#             "St. George's Drive NE",
#             'Sunridge Boulevard NE',
#             'Sunridge Way NE',
#             'Taralake Common NE',
#             'Taralake Heath NE',
#             'Taralake Way NE',
#             'Taralea Park NE',
#             'Taravista Drive NE',
#             'Taravista Way NE',
#             'Temple Drive NE',
#             'Templebow Place NE',
#             'Templebow Road NE',
#             'Templebow Way NE',
#             'Templeby Lane NE',
#             'Templegreen Road NE',
#             'Templehill Road NE',
#             'Templemont Road NE',
#             'Templemont Way NE',
#             'Valleyview Road NE',
#             'Westwinds Crescent NE',
#             'Westwinds Drive NE',
#             'Whitehorn Drive NE',
#             'Whitehorn Road NE',
#             'Whiteridge Way NE']),
#  'NE1': set(['Pinetree Road NE1']),
#  'NEw': set(['57 Avenue NEw']),
#  'NW': set(['1 Avenue NW',
#             '1 Street NW',
#             '10 Avenue NW',
#             '10 Street NW',
#             '100 Dalgleish Bay NW',
#             '100 Hampshire Court NW',
#             '100 Rocky Ridge Mews NW',
#             '1000 Varsity Estates Place NW',
#             '10A Street NW',
#             '11 Avenue NW',
#             '110 Avenue NW',
#             '112 Avenue NW',
#             '11Avenue NW',
#             '12 Avenue NW',
#             '12 Street NW',
#             '13 Avenue NW',
#             '14 Ave. NW',
#             '14 Avenue NW',
#             '14 Street NW',
#             '15 Avenue NW',
#             '15 Street NW',
#             '1506 Varsity Estates Drive NW',
#             '1508 Varsity Estates Drive NW',
#             '1510 Varsity Estates Drive NW',
#             '16 Avenue NW',
#             '16 Street NW',
#             '16A Street NW',
#             '16th Ave. NW',
#             '17 Avenue NW',
#             '17 Street NW',
#             '18 Avenue NW',
#             '18 Street NW',
#             '18A Street NW',
#             '19 Avenue NW',
#             '19 Street NW',
#             '2 Avenue NW',
#             '2 Street NW',
#             '20 Avenue NW',
#             '20 Street NW',
#             '200 Dalgleish Bay NW',
#             '200 Ranchero Place NW',
#             '200 Varsity Estates Terrace NW',
#             '21 Avenue NW',
#             '21 Street NW',
#             '22 Avenue NW',
#             '22 Street NW',
#             '2215 Uxbridge Drive NW',
#             '23 Street NW',
#             '24 Avenue NW',
#             '24 Street NW',
#             '25 Avenue NW',
#             '26 Avenue NW',
#             '27 Avenue NW',
#             '28 Avenue NW',
#             '29 Avenue NW',
#             '29 Steet NW',
#             '29 Street NW',
#             '3 Avenue NW',
#             '3 Street NW',
#             '30 Avenue NW',
#             '300 Dalgeish Bay NW',
#             '300 Rachview Mews NW',
#             '31 Avenue NW',
#             '31 Street NW',
#             '32 Avenue NW',
#             '32 Street NW',
#             '33 Street NW',
#             '34 Avenue NW',
#             '34 Street NW',
#             '35 Avenue NW',
#             '36 Avenue NW',
#             '36 St. NW',
#             '36 Street NW',
#             '37 Street NW',
#             '39 Avenue NW',
#             '4 Avenue NW',
#             '4 Street NW',
#             '40 Avenue NW',
#             '40 Street NW',
#             '400 Hampshire Court NW',
#             '41 Street NW',
#             '43 Avenue NW',
#             '46 Street NW',
#             '47 Avenue NW',
#             '48 Avenue NW',
#             '49 Street NW',
#             '4A Street NW',
#             '4th Avenue NW',
#             '5 Avenue NW',
#             '5 Street NW',
#             '50 Street NW',
#             '500 Hampshire Court NW',
#             '500 Varsity Estates Place NW',
#             '52 Avenue NW',
#             '52 Street NW',
#             '53 Avenue NW',
#             '53 Street NW',
#             '54 Street NW',
#             '58 Street NW',
#             '5A Street NW',
#             '6 Street NW',
#             '600 Varsity Estates Place NW',
#             '61 Avenue NW',
#             '63 Street NW',
#             '64 Avenue NW',
#             '66 Avenue NW',
#             '68 Avenue NW',
#             '69 St NW',
#             '69 Street NW',
#             '7 Avenue NW',
#             '7 Street NW',
#             '72 Avenue NW',
#             '73 Street NW',
#             '77 Street NW',
#             '78 Avenue NW',
#             '78 Street NW',
#             '8 Avenue NW',
#             '85 Street NW',
#             '9 Avenue NW',
#             '9 Street NW',
#             'Arbour Crest Drive NW',
#             'Arbour Crest Mews NW',
#             'Arbour Crest Rise NW',
#             'Arbour Gen Close NW',
#             'Arbour Lake Road NW',
#             'Arbour Ridge Heights NW',
#             'Banff Trail NW',
#             'Baroc Road NW',
#             'Barrett Drive NW',
#             'Bearspaw Dam Road NW',
#             'Beddington Boulevard NW',
#             'Bell Street NW',
#             'Berkshire Boulevard NW',
#             'Bermuda Drive NW',
#             'Bermuda Road NW',
#             'Berwick Crescent NW',
#             'Berwick Drive NW',
#             'Berwick Hill NW',
#             'Bow Crescent NW',
#             'Bowness Centre NW',
#             'Bowness Road NW',
#             'Bowridge Crescent NW',
#             'Bowridge Drive NW',
#             'Bowwood Drive NW',
#             'Brantford Drive NW',
#             'Brecken Road NW',
#             'Brenner Drive NW',
#             'Brentwod Boulevard NW',
#             'Brentwood Boulevard NW',
#             'Brentwood Road NW',
#             'Briar Crescent NW',
#             'Broadview Road NW',
#             'Brownsea Drive NW',
#             'Buckboard Road NW',
#             'Buckthorn Road NW',
#             'Burgess Drive NW',
#             'Cambridge Road NW',
#             'Campus Place NW',
#             'Cannon Road NW',
#             'Capital Hill Crescent NW',
#             'Capitol Hill Crescent NW',
#             'Carmangay Crescent NW',
#             'Carney Road NW',
#             'Center Street NW',
#             'Centre Street NW',
#             'Chapel Road NW',
#             'Charleswood Drive NW',
#             'Cherokee Drive NW',
#             'Chicoutimi Drive NW',
#             'Chilcotin Road NW',
#             'Chippewa Road NW',
#             'Citadel Crest Dr NW',
#             'Citadel Crest Park NW',
#             'Citadel Drive NW',
#             'Citadel Hills Green NW',
#             'Citadel Meadow Close NW',
#             'Citadel Meadow Crescent NW',
#             'Citadel Ridge Close NW',
#             'Citadel Way NW',
#             'Cochrane Road NW',
#             'Collegiate Boulevard NW',
#             'Collegiate Court NW',
#             'Collegiate Place NW',
#             'Collingwood Drive NW',
#             'Conrad Dr NW',
#             'Conrad Drive NW',
#             'Cornell Road NW',
#             'Cosgrove Street NW',
#             'Country Hills Boulevard NW',
#             'Country Hills Court NW',
#             'Country Hills Drive NW',
#             'Country Hills Landing NW',
#             'Crescent Road NW',
#             'Crowchild Trail NW',
#             'Crowfoot Crescent NW',
#             'Crowfoot Rise NW',
#             'Crowfoot Terrace NW',
#             'Crowfoot Way NW',
#             'Cumberland Drive NW',
#             'Dailyn Street NW',
#             'Dalarna Bay NW',
#             'Dalbeattie Green NW',
#             'Dalbeattie Hill NW',
#             'Dalbrook Bay NW',
#             'Dalcastle Close NW',
#             'Dalcastle Crescent NW',
#             'Dalcastle Drive NW',
#             'Dalcastle Link NW',
#             'Dalcastle Mews NW',
#             'Dalcastle Place NW',
#             'Dalcastle Way NW',
#             'Dalcroft Crescent NW',
#             'Dalcroft Hill NW',
#             'Dalford Hill NW',
#             'Dalford Road NW',
#             'Dalgetty Bay NW',
#             'Dalgetty Drive NW',
#             'Dalgetty Hill NW',
#             'Dalgleish Road NW',
#             'Dalham Crescent NW',
#             'Dalhart Hill NW',
#             'Dalhart Road NW',
#             'Dalhousie Crescent NW',
#             'Dalhousie Drive NW',
#             'Dalhousie Road NW',
#             'Dalhurst Crescent NW',
#             'Dalhurst Gate NW',
#             'Dalhurst Place NW',
#             'Dalhurst Way NW',
#             'Dalkeith Hill NW',
#             'Dalmarnock Crescent NW',
#             'Dalmarnock Green NW',
#             'Dalmead Crescent NW',
#             'Dalmeny Bay NW',
#             'Dalmeny Gate NW',
#             'Dalmeny Hill NW',
#             'Dalridge Hill NW',
#             'Dalroy Crescent NW',
#             'Dalrymple Crescent NW',
#             'Dalrymple Green NW',
#             'Dalrymple Hill NW',
#             'Dalrymple Way NW',
#             'Dalsby Gate NW',
#             'Dalsby Road NW',
#             'Dalton Bay NW',
#             'Dalton Drive NW',
#             'Dalwood Way NW',
#             'Dalzell Place NW',
#             'Eamon Road NW',
#             'Edelweiss Point NW',
#             'Edenwold Drive NW',
#             'Edgebrook Boulevard NW',
#             'Edgebrook Rise NW',
#             'Edgebyne Crescent NW',
#             'Edgehill Close NW',
#             'Edgehill Drive NW',
#             'Edgeland Bay NW',
#             'Edgeland Close NW',
#             'Edgeland Road NW',
#             'Edgemont Boulevard NW',
#             'Edgemont Drive NW',
#             'Edgepark Boulevard NW',
#             'Edgevalley Circle NW',
#             'Evanspark Gardens NW',
#             'Evanspark Road NW',
#             'Evanston Drive NW',
#             'Exshaw Road NW',
#             'Hampshire Circle NW',
#             'Hamptons Boulevard NW',
#             'Hamptons Drive NW',
#             'Hamptons Park NW',
#             'Hamptons Way NW',
#             'Harlow Avenue NW',
#             'Hawcliffe Mews NW',
#             'Hawkhill Mews NW',
#             'Hawkhill Way NW',
#             'Hawkland Place NW',
#             'Hawkside Mews NW',
#             'Hawkstone Drive NW',
#             'Hawkwood Boulevard NW',
#             'Hawkwood Drive NW',
#             'Hidden Creek Road NW',
#             'Hidden Ranch Boulevard NW',
#             'Hidden Ranch Circle NW',
#             'Hidden Ranch Court NW',
#             'Hidden Ranch Crescent NW',
#             'Hidden Ranch Terrace NW',
#             'Hidden Ridge Close NW',
#             'Hidden Ridge Court NW',
#             'Hidden Valley Drive NW',
#             'Holmwood Avenue NW',
#             'Home Road NW',
#             'John Laurie Boulevard NW',
#             'Kensington Crescent NW',
#             'Kensington Road NW',
#             'MacEwan Drive NW',
#             'MacEwan Park Manor NW',
#             'Macewan Park Manor NW',
#             'Macewan Park View NW',
#             'McKay Road NW',
#             'Memorial Dr NW',
#             'Memorial Drive NW',
#             'Monserrat Drive NW',
#             'Montgomery Avenue NW',
#             'Montgomery Boulevard NW',
#             'Morley Trail NW',
#             'Namaka Crescent NW',
#             'Nolan Hill Boulevard NW',
#             'Nolan Hill Drive NW',
#             'North Haven Drive NW',
#             'Northland Dr. NW',
#             'Northland Drive NW',
#             'Northmount Drive NW',
#             'Nose Hill Drive NW',
#             'Panamount Boulevard NW',
#             'Panamount Circle NW',
#             'Panamount Hill NW',
#             'Panamount Way NW',
#             'Panatella Boulevard NW',
#             'Panatella Hill NW',
#             'Panorama Hills Boulevard NW',
#             'Panorama Hills Drive NW',
#             'Parkdale Boulevard NW',
#             'Parkdale Crescent NW',
#             'Point Drive NW',
#             'Point McKay Crescent NW',
#             'Point McKay Grove NW',
#             'Ranch Estates Drive NW',
#             'Ranch Estates Place NW',
#             'Ranchero Drive NW',
#             'Ranchero Place NW',
#             'Ranchlands Boulevard NW',
#             'Ranchlands Way NW',
#             'Ranchview Drive NW',
#             'Ranchview Link NW',
#             'Ranchview Road NW',
#             'Range Crescent NW',
#             'Range Drive NW',
#             'Range Way NW',
#             'Research Road NW',
#             'Research Way NW',
#             'Reunion Boulevard NW',
#             'Rocky Ridge Drive NW',
#             'Rocky Ridge Road NW',
#             'Rocky Vista Gardens NW',
#             'Rockyvalley Drive NW',
#             'Rosevale Drive NW',
#             'Royal Birch Boulevard NW',
#             'Royal Elm Drive NW',
#             'Royal Oak Drive NW',
#             'Royal Oak Way NW',
#             'Royal Vista Drive NW',
#             'Royal Vista Way NW',
#             'Sage Hill Gate NW',
#             'Sage Hill Plaza NW',
#             'Sage Hill Way NW',
#             'Sage Valley Drive NW',
#             'Sandarac Drive NW',
#             'Sarcee Trail NW',
#             'Scenic Acres Boulevard NW',
#             'Scenic Acres Drive NW',
#             'Scenic Acres Gate NW',
#             'Scenic Bow Road NW',
#             'Scotia Landing NW',
#             'Scurfield Drive NW',
#             'Scurfield Way NW',
#             'Shaganappi Tr NW',
#             'Shaganappi Trail NW',
#             'Sherwood Boulevard NW',
#             'Sherwood Crescent NW',
#             'Silver Mead Bay NW',
#             'Silver Mead Crescent NW',
#             'Silver Mead Road NW',
#             'Silver Ridge Drive NW',
#             'Silver Springs Boulevard NW',
#             'Silver Springs Crescent NW',
#             'Silver Springs Drive NW',
#             'Silver Springs Gate NW',
#             'Silvergrove Drive NW',
#             'Silvermead Road NW',
#             'Symons Valley Parkway NW',
#             'Symons Valley Rd NW',
#             'Symons Valley Road NW',
#             'Thornton Road NW',
#             'Tipton Road NW',
#             'Tuscany Blvd NW',
#             'Tuscany Boulevard NW',
#             'Tuscany Drive NW',
#             'Tuscany Hills Close NW',
#             'Tuscany Hills Road NW',
#             'Tuscany Hills Terrace NW',
#             'Tuscany Springs Circle NW',
#             'Tuscany Way NW',
#             'University Drive NW',
#             'University Gate NW',
#             'Urbana Road NW',
#             'Uster Road NW',
#             'Utah Drive NW',
#             'Uxbridge Dr NW',
#             'Uxbridge Drive NW',
#             'Valiant Drive NW',
#             'Valiant Place NW',
#             'Valley Meadow Close NW',
#             'Valley Ridge Boulevard NW',
#             'Valley Ridge Drive NW',
#             'Vandale Place NW',
#             'Varsity Dr NW',
#             'Varsity Drive NW',
#             'Varsity Estates Circle NW',
#             'Varsity Estates Close NW',
#             'Varsity Estates Crescent NW',
#             'Varsity Estates Drive NW',
#             'Varsity Estates Green NW',
#             'Varsity Estates Grove NW',
#             'Varsity Estates Link NW',
#             'Varsity Estates Mews NW',
#             'Varsity Estates Place NW',
#             'Varsity Estates Terrace NW',
#             'Varsity Estates View NW',
#             'Varsity Place NW',
#             'Vicary Place NW',
#             'Viscount Drive NW',
#             'Westmount Boulevard NW',
#             'Westmount Road NW']),
#  'NWw': set(['77 Street NWw']),
#  'Park': set(['Manyhorses Park',
#               'Mountain View Park',
#               'Noorduyn Park',
#               "Prince's Island Park"]),
#  'Plaza': set(['Sunpark Plaza']),
#  'Point': set(['Bracken Point', 'Park Point']),
#  'Rise': set(['Elbow Rise']),
#  'Roads': set(['Wrangler Roads']),
#  'S.W.': set(['19 Street S.W.', 'Hillcrest Avenue S.W.', 'Stanley Road S.W.']),
#  'SE': set(['1 Street SE',
#             '10 Avenue SE',
#             '10 Street SE',
#             '100 McKenzie Lake Bay SE',
#             '100 Street SE',
#             '106 Avenue SE',
#             '107 Avenue SE',
#             '11 Avenue SE',
#             '11 Street SE',
#             '110 Avenue SE',
#             '112 Avenue SE',
#             '114 Avenue SE',
#             '118 Avenue SE',
#             '12 Avenue SE',
#             '12 Street SE',
#             '120 Avenue SE',
#             '1235 26th Ave. SE',
#             '126 Avenue SE',
#             '12A Street SE',
#             '13 Avenue SE',
#             '13 Street SE',
#             '130 Avenue SE',
#             '137 Avenue SE',
#             '13A Street SE',
#             '14 Avenue SE',
#             '14 Street SE',
#             '146 Avenue SE',
#             '15 Avenue SE',
#             '15 St SE',
#             '15 Street SE',
#             '16 Street SE',
#             '17 Avenue SE',
#             '17 Street SE',
#             '17 avenue SE',
#             '17A Street SE',
#             '18 Avenue SE',
#             '18 Street SE',
#             '19 Avenue SE',
#             '19 Street SE',
#             '194 Avenue SE',
#             '2 Avenue SE',
#             '2 Street SE',
#             '20 Avenue SE',
#             '200 Auburn Bay Cove SE',
#             '200 McKenzie Lake Bay SE',
#             '20A Street SE',
#             '21 Avenue SE',
#             '21 Street SE',
#             '21A Street SE',
#             '22 Street SE',
#             '23 AVE SE',
#             '23 Avenue SE',
#             '24 Avenue SE',
#             '24 Street SE',
#             '25 Avenue SE',
#             '25 Street SE',
#             '26 Avenue SE',
#             '26 Street SE',
#             '27 Street SE',
#             '28 Avenue SE',
#             '28 Street SE',
#             '29 Street SE',
#             '3 Avenue SE',
#             '3 Street SE',
#             '30 Avenue SE',
#             '30 Street SE',
#             '300 McKenzie Lake Bay SE',
#             '30th Street SE',
#             '31 Street SE',
#             '32 Street SE',
#             '33 Street SE',
#             '34 Avenue SE',
#             '34 Street SE',
#             '35 Street SE',
#             '36 Street SE',
#             '39 Avenue SE',
#             '39 Street SE',
#             '4 Avenue SE',
#             '4 Street SE',
#             '40 Street SE',
#             '400 McKenzie Lake Bay SE',
#             '41 Street SE',
#             '42 Avenue SE',
#             '42 Street SE',
#             '4216-54 Ave. SE',
#             '44 Street SE',
#             '46 Avenue SE',
#             '46 Street SE',
#             '47 Street SE',
#             '48 Avenue SE',
#             '48 Street SE',
#             '49 Avenue SE',
#             '4A Avenue SE',
#             '5 Avenue SE',
#             '5 Street SE',
#             '50 Avenue SE',
#             '50 Street SE',
#             '500 McKenzie Lake Bay SE',
#             '51 Avenue SE',
#             '51 Street SE',
#             '52 Avenue SE',
#             '52 Street SE',
#             '53 Avenue SE',
#             '53 Street SE',
#             '54 Avenue SE',
#             '54 Street SE',
#             '55 Street SE',
#             '56 Avenue SE',
#             '56 Street SE',
#             '57 Street SE',
#             '58 Avenue SE',
#             '58 Street SE',
#             '58th Ave SE',
#             '59 Avenue SE',
#             '6 Avenue SE',
#             '6 Street SE',
#             '60 Street SE',
#             '600 McKenzie Lake Bay SE',
#             '61 Avenue SE',
#             '62 Avenue SE',
#             '62 Street SE',
#             '64 Avenue SE',
#             '66 Avenue SE',
#             '66 Street SE',
#             '68 Street SE',
#             '69 Avenue SE',
#             '7 Avenue SE',
#             '70 Avenue SE',
#             '700 McKenzie Lake Bay SE',
#             '72 Avenue SE',
#             '73 Avenue SE',
#             '74 Avenue SE',
#             '74 Street SE',
#             '76 Avenue SE',
#             '77 Avenue SE',
#             '78 Avenue SE',
#             '79 Avenue SE',
#             '7th St SE',
#             '8 Avenue SE',
#             '8 Street SE',
#             '80 Avenue SE',
#             '81 Street SE',
#             '83 Avenue SE',
#             '84 Avenue SE',
#             '84 Street SE',
#             '86 Avenue SE',
#             '9 Avenue SE',
#             '9 Street SE',
#             '90 Ave SE',
#             '90 Avenue SE',
#             '92 Avenue SE',
#             '94 Ave SE',
#             '94 Ave. SE',
#             '94 Avenue SE',
#             '96 Avenue SE',
#             '99 Avenue SE',
#             '9th Avenue SE',
#             'Acadia Drive SE',
#             'Agate Crescent SE',
#             'Anderson Rd. SE',
#             'Anderson Road SE',
#             'Andreson Rd. SE',
#             'Arbour Crescent SE',
#             'Auburn Bay Avenue SE',
#             'Auburn Bay Boulevard SE',
#             'Auburn Bay Heights SE',
#             'Auburn Bay Lane SE',
#             'Auburn Bay Manor SE',
#             'Auburn Crest Way SE',
#             'Auburn Meadows Boulevard SE',
#             'Bannister Road SE',
#             'Barlow Trail SE',
#             'Bellevue Avenue SE',
#             'Big Four Trail SE',
#             'Blackfoot Trail SE',
#             'Bonaventure Drive SE',
#             'Bow Bottom Trail SE',
#             'Bow Bottom Trial SE',
#             'Brightondale Park SE',
#             'Brightonstone Grove SE',
#             'Builders Road SE',
#             'Canyon Meadows Dr SE',
#             'Canyon Meadows Drive SE',
#             'Center Street SE',
#             'Chaparral Drive SE',
#             'Chaparral Ridge Drive SE',
#             'Copperpond Common SE',
#             'Copperstone Road SE',
#             'Corral Trail SE',
#             'Cramond Green SE',
#             'Cranarch Rd SE',
#             'Cranarch Road SE',
#             'Cranberry Road SE',
#             'Cranbrook Place SE',
#             'Cranbrook Way SE',
#             'Cranridge Terrace SE',
#             'Cranston Avenue SE',
#             'Cranston Drive SE',
#             'Cranston Gate SE',
#             'Cranston Rd SE',
#             'Cranston Road SE',
#             'Cranston Way SE',
#             'Cranwell Crescent SE',
#             'Cranwell Manor SE',
#             'Dartmouth Road SE',
#             'Deer Ridge Drive SE',
#             'Deerpoint Road SE',
#             'Dermot Baldwin Way SE',
#             'Diamond Drive SE',
#             'Douglas Glen Boulevard SE',
#             'Douglas Park Boulevard SE',
#             'Douglasdale Boulevard SE',
#             'Douglasview Road SE',
#             'Dover Ridge Drive SE',
#             'Dufferein Place SE',
#             'Endeavor Drive SE',
#             'Enterprise Way SE',
#             'Erin Park Drive SE',
#             'Exploration Avenue SE',
#             'Fairmount Dr. SE',
#             'Fairmount Drive SE',
#             'Fisher Road SE',
#             'Fisher Street SE',
#             'Flint Road SE',
#             'Forego Avenue SE',
#             'Fortalice Crescent SE',
#             'Front Street SE',
#             'Fyffe Road SE',
#             'Grandstand Trail SE',
#             'Heritage Dr. SE',
#             'Heritage Drive SE',
#             'Heritage Gate SE',
#             'Heritage Meadows Way SE',
#             'High St SE',
#             'High Street SE',
#             'Highfield Crescent SE',
#             'Hubalta Road SE',
#             'Industry Way SE',
#             'Initiative Avenue SE',
#             'Inverness Park SE',
#             'Inverness Square SE',
#             'Kingsland Way SE',
#             'Lake Adams Crescent SE',
#             'Lake Bonavista Drive SE',
#             'Lake Fraser Drive SE',
#             'Lake Ontario Road SE',
#             'Lake Placid Drive SE',
#             'Lake Placid Green SE',
#             'Lake Sylvan Dr. SE',
#             'Lake Twintree Drive SE',
#             'Lake Twintree Road SE',
#             'Lake Twintree Way SE',
#             'Legacy Circle SE',
#             'Legacy Green SE',
#             'Lynnview Court SE',
#             'Lynnview Road SE',
#             'MacDonald Avenue SE',
#             'MacLeod Trail SE',
#             'Macleod Tr SE',
#             'Macleod Trail SE',
#             'Maggie Street SE',
#             'Mahogany Lane SE',
#             'Mahogany Park SE',
#             'Mahogany Passage SE',
#             'Main Street SE',
#             'Manitou Road SE',
#             'Maplecreek Drive SE',
#             'Maplecroft Road SE',
#             'Mapleglade Drive SE',
#             'Mapleglen Crescent SE',
#             'Mapleridge Crescent SE',
#             'Mapleshire Crescent SE',
#             'McIvor Boulevard SE',
#             'McKenzie Lake Boulevard SE',
#             'McKenzie Lake Way SE',
#             'McKenzie Towne Avenue SE',
#             'McKenzie Towne Boulevard SE',
#             'McKenzie Towne Common SE',
#             'McKenzie Towne Dr SE',
#             'McKenzie Towne Drive SE',
#             'McKenzie Towne Gate SE',
#             'McKenzie Towne Link SE',
#             'McKenzie Towne Manor SE',
#             'McKenzie Towne Row SE',
#             'McKenzie Towne Square SE',
#             'McKenzie Towne Villas SE',
#             'Midlake Boulevard SE',
#             'Midpark Boulevard SE',
#             'Midpark Rise SE',
#             'Midpark Way SE',
#             'Millican Road SE',
#             'Mount Douglas Close SE',
#             'Mount McKenzie Drive SE',
#             'New Brighton Drive SE',
#             'Ogden Crescent SE',
#             'Ogden Dale Road SE',
#             'Ogden Road SE',
#             'Olympia Bay SE',
#             'Olympia Place SE',
#             'Olympic Way SE',
#             'Parkglen Crescent SE',
#             'Parkglen Place SE',
#             'Parkland Boulevard SE',
#             'Parkland Way SE',
#             'Parkside Drive SE',
#             'Parkview Way SE',
#             'Penbrooke Drive SE',
#             'Pensacola Way SE',
#             'Prestwick Avenue SE',
#             'Prestwick Circle SE',
#             'Prestwick Drive SE',
#             'Promenade Way SE',
#             'Providence Boulevard SE',
#             'Quarry Park Boulevard SE',
#             'Quarry Park Road SE',
#             'Queensland Drive SE',
#             'Radcliffe Drive SE',
#             'Radisson Drive SE',
#             'Railway Street SE',
#             'Ramsay Street SE',
#             'Riverbrook Court SE',
#             'Riverbrook Place SE',
#             'Riverbrook Road SE',
#             'Riverbrook Way SE',
#             'Riverfront Avenue SE',
#             'Riverglen Drive SE',
#             'Rivervalley Drive SE',
#             'Sable Drive SE',
#             'Saddledome Rise SE',
#             'Salisbury Street SE',
#             'Seton Drive SE',
#             'Seton Way SE',
#             'Shalom Way SE',
#             'Shawville Blvd. SE',
#             'Shawville Boulevard SE',
#             'Shepard Place SE',
#             'Shepard Road SE',
#             'Southland Dr. SE',
#             'Spiller Road SE',
#             'Sun Park Plaza SE',
#             'Sun Valley Boulevard SE',
#             'Sun Valley Drive SE',
#             'Sunbank Way SE',
#             'Suncastle Drive SE',
#             'Suncrest Way SE',
#             'Sunhurst Crescent SE',
#             'Sunmills Drive SE',
#             'Sunmount Court SE',
#             'Sunmount Gardens SE',
#             'Sunmount Green SE',
#             'Sunmount Rise SE',
#             'Sunpark Drive SE',
#             'Sunpark Plaza SE',
#             'Technology Way SE',
#             'Venture Avenue SE',
#             'Walden Gate SE',
#             'Walden Gates SE',
#             'Warren Road SE',
#             'Willingdon Boulevard SE',
#             'Willow Park Drive SE']),
#  'SEw': set(['Fairmount Drive SEw']),
#  'SW': set(['1 Avenue SW',
#             '1 St SW',
#             '1 Street SW',
#             '10 Avenue SW',
#             '10 Street SW',
#             '100 Cedardale Place SW',
#             '100 Killarney Glen Court SW',
#             '100 Wood Valley Court SW',
#             '101 Street SW',
#             '106 Avenue SW',
#             '107 Avenue SW',
#             '10th Ave SW',
#             '10th Street SW',
#             '11 Ave SW',
#             '11 Avenue SW',
#             '11 Street SW',
#             '11th Ave SW',
#             '12 Avenue SW',
#             '12 Street SW',
#             '12th Avenue SW',
#             '13 Avenue SW',
#             '13 Street SW',
#             '14 Avenue SW',
#             '14 Street SW',
#             '14A Street SW',
#             '15 Avenue SW',
#             '15 Street SW',
#             '16 Avenue SW',
#             '16 Street SW',
#             '162 Avenue SW',
#             '17 Ave SW',
#             '17 Ave. SW',
#             '17 Avenue SW',
#             '17 Street SW',
#             '17B Street SW',
#             '17th Avenue SW',
#             '17th Street SW',
#             '18 Avenue SW',
#             '18 Street SW',
#             '19 Avenue SW',
#             '19 Street SW',
#             '1A Street SW',
#             '1st St. SW',
#             '2 Avenue SW',
#             '2 Street SW',
#             '20 Street SW',
#             '200 Cedardale Place SW',
#             '200 Killarney Glen Court SW',
#             '200 Wood Valley Court SW',
#             '21 Avenue SW',
#             '21 Street SW',
#             '22 Street SW',
#             '23 Avenue SW',
#             '24 Hemlock Cres SW',
#             '24 Street SW',
#             '25 Avenue SW',
#             '26 Avenue SW',
#             '26 Street SW',
#             '28 Avenue SW',
#             '28 Street SW',
#             '29 Avenue SW',
#             '29 Street SW',
#             '2nd Street SW',
#             '3 Avenue SW',
#             '3 Street SW',
#             '300 Killarney Glen Court SW',
#             '33 Ave SW',
#             '33 Avenue SW',
#             '33 Street SW',
#             '34 Avenue SW',
#             '34 Street SW',
#             '35 Avenue SW',
#             '35 Street SW',
#             '36 Avenue SW',
#             '36 Street SW',
#             '37 Street SW',
#             '38 Avenue SW',
#             '38 Street SW',
#             '4 Avenue SW',
#             '4 Street SW',
#             '40 Avenue SW',
#             '40 Street SW',
#             '400 Killarney Glen Court SW',
#             '41 Avenue SW',
#             '41 St SW',
#             '41 Street SW',
#             '42 Avenue SW',
#             '42 Street SW',
#             '45 Street SW',
#             '47 Avenue SW',
#             '4A Street SW',
#             '4th Street SW',
#             '5 Avenue SW',
#             '5 Street SW',
#             '50 Avenue SW',
#             '50 Street SW',
#             '500 Killarney Glen Court SW',
#             '51 Street SW',
#             '5255 Richmond Road SW',
#             '53 Avenue SW',
#             '54 Avenue SW',
#             '56 Avenue SW',
#             '57 Avenue SW',
#             '58 Avenue SW',
#             '5A Street SW',
#             '5th Avenue SW',
#             '5th Street SW',
#             '6 Ave SW',
#             '6 Avenue SW',
#             '6 Street SW',
#             '600 Killarney Glen Court SW',
#             '61st Ave SW',
#             '62 Avenue SW',
#             '63 Avenue SW',
#             '66 Avenue SW',
#             '67 Avenue SW',
#             '69 Street SW',
#             '6th Avenue SW',
#             '7 Avenue SW',
#             '7 Street SW',
#             '73 Avenue SW',
#             '75 Avenue SW',
#             '77 Street SW',
#             '78 Avenue SW',
#             '7A Street SW',
#             '8 Ave SW',
#             '8 Avenue SW',
#             '8 St SW',
#             '8 Street SW',
#             '84 Avenue SW',
#             '85 Street SW',
#             '86 Avenue SW',
#             '87 Avenue SW',
#             '89 Avenue SW',
#             '89 St SW',
#             '89 Street SW',
#             '8th Ave SW',
#             '8th Avenue SW',
#             '8th Street SW',
#             '9 Avenue SW',
#             '9 Street SW',
#             '90 Avenue SW',
#             '90th Avenue SW',
#             '92 Avenue SW',
#             '96 Avenue SW',
#             '9th Avenue SW',
#             'Ambrose Circle SW',
#             'Anderson Station Way SW',
#             'Aspen Glen Landing SW',
#             'Aspen Hills Drive SW',
#             'Aspenshire Drive SW',
#             'Bagot Avenue SW',
#             'Barclay Parade SW',
#             'Battleford Avenue SW',
#             'Beverley Boulevard SW',
#             'Bow Trail SW',
#             'Bracewood Drive SW',
#             'Braeside Drive SW',
#             'Breskens Drive SW',
#             'Bridleridge Way SW',
#             'Britannia Drive SW',
#             'Brookpark Drive SW',
#             'Canada Olympic Road SW',
#             'Canata Close SW',
#             'Canfield Crescent SW',
#             'Canfield Way SW',
#             'Canova Road SW',
#             'Cantabrian Drive SW',
#             'Canterbury Drive SW',
#             'Canterville Drive SW',
#             'Cedarbrae Drive SW',
#             'Cedardale Hill SW',
#             'Cedarpark Drive SW',
#             'Coach Hill Road SW',
#             'Collicutt St SW',
#             'Couture Crescent SW',
#             'Crowchild Trail SW',
#             'Dieppe Avenue SW',
#             'Dieppe Drive SW',
#             'Discovery Ridge Way SW',
#             'Don Ethell Boulevard SW',
#             'Eau Claire Avenue SW',
#             'Elbow Dr. SW',
#             'Elbow Drive SW',
#             'Elkmont Estates Manor SW',
#             'Elkton Drive SW',
#             'Elkton Way SW',
#             'Elmont Drive SW',
#             'Elveden Drive SW',
#             'Elveden Mews SW',
#             'Elveden Point SW',
#             'Erlton Street SW',
#             'Evergreen Common SW',
#             'Everhollow Green SW',
#             'Everhollow Street SW',
#             'Everridge Drive SW',
#             'Everstone Drive SW',
#             'Eversyde Avenue SW',
#             'Eversyde Close SW',
#             'Eversyde Gardens SW',
#             'Fish Creek Boulevard SW',
#             'Flanders Avenue SW',
#             'Forand Street SW',
#             'Fountain Walk SW',
#             'Garden Lane SW',
#             'Garrison Boulevard SW',
#             'Glenmore Trail SW',
#             'Glenmount Drive SW',
#             'Glenway Drive SW',
#             'Grafton Drive SW',
#             'Haddon Road SW',
#             'Hallbrook Drive SW',
#             'Hamlet Road SW',
#             'Harcourt Road SW',
#             'Harmon Place SW',
#             'Harvery Place SW',
#             'Haultain Place SW',
#             'Haverhill Road SW',
#             'Haysboro Crescent SW',
#             'Healy Drive SW',
#             'Heritage Drive SW',
#             'Heritage Row SW',
#             'Hilgrove Crescent SW',
#             'Hillcrest Avenue SW',
#             'Hobart Road SW',
#             'Hochwald Avenue SW',
#             'Hochwald Court SW',
#             'Hollyburn Road SW',
#             'Hoover Place SW',
#             'Horton Road SW',
#             'Hyslop Drive SW',
#             'James McKevitt Road SW',
#             'Jerusalem Road SW',
#             'Johnson Place SW',
#             'Kelwood Drive SW',
#             'Kootenay Steet SW',
#             'La Caille Place SW',
#             'Lakeside Crescent SW',
#             'Lakeview Drive SW',
#             'Lancing Avenue SW',
#             'Langriville Drive SW',
#             'Larkspur Way SW',
#             'Laurentian Way SW',
#             'Lewis Drive SW',
#             'Lincoln Drive SW',
#             'Lindsay Drive SW',
#             'Longridge Drive SW',
#             'Lorne Place SW',
#             'Luxstone Boulevard SW',
#             'Lyle Avenue SW',
#             'Mackenzie Way SW',
#             'Macleod Trail SW',
#             'Macleod Trails SW',
#             'Mike Ralph Way SW',
#             'Millrise Hill SW',
#             'Montcalm Crescent SW',
#             'North Glenmore Park Road SW',
#             'Oakfield Drive SW',
#             'Oakhill Drive SW',
#             'Oakmount Court SW',
#             'Oakmount Drive SW',
#             'Oakwood Drive SW',
#             'Old Banff Coach Road SW',
#             'Palliser Drive SW',
#             'Parkhill Place SW',
#             'Patina Drive SW',
#             'Patterson Boulevard SW',
#             'PattersonDrive SW',
#             'Peacekeepers Way SW',
#             'Prominence Way SW',
#             'Pump Hill Close SW',
#             'Pumphouse Avenue SW',
#             'Pumphouse Road SW',
#             'Quesnay Wood Drive SW',
#             'Richard Road SW',
#             'Richard Way SW',
#             'Richardson Road SW',
#             'Richardson Way SW',
#             'Richmond Road SW',
#             'Rideau Road SW',
#             'Riverfront Avenue SW',
#             'Riverfront SW',
#             'Royal Avenue SW',
#             'Sabrina Road SW',
#             'Sackville Drive SW',
#             'Sacramento Drive SW',
#             'Sarcee Road SW',
#             'Scarboro Avenue SW',
#             'Scotland Street SW',
#             'Shannon Drive SW',
#             'Shannon Place SW',
#             'Shawglen Rise SW',
#             'Shawinigan Drive SW',
#             'Shawnee Manor SW',
#             'Shawnee Rise SW',
#             'Shawnessy Drive SW',
#             'Sienna Bay SW',
#             'Sienna Heights Hill SW',
#             'Sienna Heights Way SW',
#             'Sienna Hills Court SW',
#             'Sienna Hills Drive SW',
#             'Sienna Hills Place SW',
#             'Sienna Hills Terrace SW',
#             'Sienna Hills View SW',
#             'Sienna Park Bay SW',
#             'Sienna Park Drive SW',
#             'Sienna Park Terrace SW',
#             'Sienna Park View SW',
#             'Signal Hill Centre SW',
#             'Signal Hill Drive SW',
#             'Signature Close SW',
#             'Signature Rise SW',
#             'Silverado Boulevard SW',
#             'Simcoe Road SW',
#             'Sirocco Drive SW',
#             'Slopes Road SW',
#             'Somercrest Street SW',
#             'Somerset Drive SW',
#             'Somerset Gate SW',
#             'Somerset Manor SW',
#             'Somerside Crescent SW',
#             'Somervale Close SW',
#             'Somervale Court SW',
#             'Somervale Dr SW',
#             'Somervale Drive SW',
#             'Somervale Green SW',
#             'Somervale Link SW',
#             'Sonora Avenue SW',
#             'Sorrel Place SW',
#             'Southland Circle SW',
#             'Southland Dr. SW',
#             'Southland Drive SW',
#             'Southport Lane SW',
#             'Southport Rd SW',
#             'Southport Road SW',
#             'Spring Valley View SW',
#             'Spring Willow Terrace SW',
#             'Springborough Boulevard SW',
#             'Springborough Green SW',
#             'Spruce Drive SW',
#             'Spruce Meadows Trail SW',
#             'Stewart Green SW',
#             'Strathcona Boulevard SW',
#             'Strathcona Drive SW',
#             'Superior Avenue SW',
#             'Trasimene Crescent SW',
#             'Village Garden SW',
#             'Village Gardens SW',
#             'Village Heights SW',
#             'Village Mews SW',
#             'Village Terrace SW',
#             'Waterloo Drive SW',
#             'Waverly Drive SW',
#             'Wentworth Avenue SW',
#             'Wentworth Drive SW',
#             'West Coach Manor SW',
#             'West Coach Pl SW',
#             'West Coach Way SW',
#             'West Glen Crescent SW',
#             'Westminster Drive SW',
#             'Westview Drive SW',
#             'Westwood Drive SW',
#             'Wildwood Drive SW',
#             'Windermere Road SW',
#             'Winslow Crescent SW',
#             'Winston Drive SW',
#             'Wood Valley Drive SW',
#             'Wood Valley Gate SW',
#             'Wood Valley Rise SW',
#             'Wood Willow Close SW',
#             'Woodbine Boulevard SW',
#             'Woodfield Drive SW',
#             'Woodfield Way SW',
#             'Woodgreen Drive SW',
#             'Woodlark Drive SW',
#             'Woodpark Boulevard SW',
#             'Woodside Road SW',
#             'Woodview Drive SW']),
#  'SWs': set(['41 Avenue SWs']),
#  'SWw': set(['2 Avenue SWw']),
#  'South': set(['Macleod Trail South', 'River Drive South']),
#  'South-east': set(['Rivercrest Drive South-east']),
#  'South-west': set(['Everhollow Manor South-west']),
#  'St': set(['Center St']),
#  'Terrace': set(['Deerview Terrace']),
#  'View': set(['Montgomery View', 'Sunrise View']),
#  'Villas': set(['Watermark Villas']),
#  'Walk': set(['Cherrytree Walk']),
#  'n.e.': set(['airport avenue n.e.']),
#  'pathway': set(['Cranston Road regional pathway'])}
# Fairmount Drive SEw => Fairmount Drive SEw
# East Lake Blvd NE #A => East Lake Blvd NE #A
# Cherrytree Walk => Cherrytree Walk
# 3rd St SW Suite 210 => 3rd St SW Suite 210
# Township Road  210 => Township Road  210
# Range Road 51A => Range Road 51A
# Range Road  51A => Range Road  51A
# Township Road  210B => Township Road  210B
# Township Road  210A => Township Road  210A
# Vetrans Blvd. => Vetrans Blvd.
# Township Road  234 => Township Road  234
# 77 Street NWw => 77 Street NWw
# Township Road 261 => Township Road 261
# 400123 Highway 66 => 400123 Highway 66
# Township Road  204A => Township Road  204A
# ...
# Drake Landing Blvd => Drake Landing Boulevard
# Redwood Meadows Close => Redwood Meadows Close
# Wild Rose Close => Wild Rose Close
# Coyote Close => Coyote Close
# Auburn Sound Close => Auburn Sound Close
# Wolf Close => Wolf Close
# Pinetree Road NE1 => Pinetree Road NE1
# Range Road 293 => Range Road 293
# Salisbury Street SE => Salisbury Street Southeast
# Exploration Avenue SE => Exploration Avenue Southeast
# Inverness Park SE => Inverness Park Southeast
# Cranston Drive SE => Cranston Drive Southeast
# McKenzie Lake Boulevard SE => McKenzie Lake Boulevard Southeast
# Rivervalley Drive SE => Rivervalley Drive Southeast
# 54 Avenue SE => 54 Avenue Southeast
# McKenzie Towne Row SE => McKenzie Towne Row Southeast
# 2 Avenue SE => 2 Avenue Southeast
# 126 Avenue SE => 126 Avenue Southeast
# Lake Placid Drive SE => Lake Placid Drive Southeast
# Hubalta Road SE => Hubalta Road Southeast
# Cranwell Manor SE => Cranwell Manor Southeast
# 56 Avenue SE => 56 Avenue Southeast
# Andreson Rd. SE => Andreson Rd. Southeast
# McKenzie Towne Link SE => McKenzie Towne Link Southeast
# Initiative Avenue SE => Initiative Avenue Southeast
# Big Four Trail SE => Big Four Trail Southeast
# 5 Avenue SE => 5 Avenue Southeast
# 27 Street SE => 27 Street Southeast
# Sunhurst Crescent SE => Sunhurst Crescent Southeast
# Inverness Square SE => Inverness Square Southeast
# 1235 26th Ave. SE => 1235 26th Ave. Southeast
# 7th St SE => 7th St Southeast
# Southland Dr. SE => Southland Dr. Southeast
# 114 Avenue SE => 114 Avenue Southeast
# 17 Street SE => 17 Street Southeast
# 51 Avenue SE => 51 Avenue Southeast
# Suncrest Way SE => Suncrest Way Southeast
# 24 Street SE => 24 Street Southeast
# 25 Avenue SE => 25 Avenue Southeast
# New Brighton Drive SE => New Brighton Drive Southeast
# Chaparral Ridge Drive SE => Chaparral Ridge Drive Southeast
# 500 McKenzie Lake Bay SE => 500 McKenzie Lake Bay Southeast
# 3 Street SE => 3 Street Southeast
# Midpark Boulevard SE => Midpark Boulevard Southeast
# Lake Bonavista Drive SE => Lake Bonavista Drive Southeast
# 11 Street SE => 11 Street Southeast
# Auburn Bay Boulevard SE => Auburn Bay Boulevard Southeast
# 130 Avenue SE => 130 Avenue Southeast
# 107 Avenue SE => 107 Avenue Southeast
# 44 Street SE => 44 Street Southeast
# 21 Street SE => 21 Street Southeast
# Midpark Rise SE => Midpark Rise Southeast
# 1 Street SE => 1 Street Southeast
# 7 Avenue SE => 7 Avenue Southeast
# 50 Street SE => 50 Street Southeast
# Mahogany Passage SE => Mahogany Passage Southeast
# Copperpond Common SE => Copperpond Common Southeast
# 55 Street SE => 55 Street Southeast
# McKenzie Towne Common SE => McKenzie Towne Common Southeast
# 17 avenue SE => 17 avenue Southeast
# 50 Avenue SE => 50 Avenue Southeast
# 60 Street SE => 60 Street Southeast
# 81 Street SE => 81 Street Southeast
# Mapleshire Crescent SE => Mapleshire Crescent Southeast
# Legacy Circle SE => Legacy Circle Southeast
# 200 McKenzie Lake Bay SE => 200 McKenzie Lake Bay Southeast
# Corral Trail SE => Corral Trail Southeast
# 28 Avenue SE => 28 Avenue Southeast
# Main Street SE => Main Street Southeast
# 59 Avenue SE => 59 Avenue Southeast
# Shepard Road SE => Shepard Road Southeast
# Cranbrook Way SE => Cranbrook Way Southeast
# Parkside Drive SE => Parkside Drive Southeast
# Cranston Avenue SE => Cranston Avenue Southeast
# Quarry Park Road SE => Quarry Park Road Southeast
# Lake Placid Green SE => Lake Placid Green Southeast
# Acadia Drive SE => Acadia Drive Southeast
# 8 Street SE => 8 Street Southeast
# 194 Avenue SE => 194 Avenue Southeast
# Manitou Road SE => Manitou Road Southeast
# Riverfront Avenue SE => Riverfront Avenue Southeast
# Cranarch Road SE => Cranarch Road Southeast
# Deer Ridge Drive SE => Deer Ridge Drive Southeast
# Sunmount Gardens SE => Sunmount Gardens Southeast
# Shalom Way SE => Shalom Way Southeast
# Millican Road SE => Millican Road Southeast
# 74 Street SE => 74 Street Southeast
# 74 Avenue SE => 74 Avenue Southeast
# Warren Road SE => Warren Road Southeast
# 77 Avenue SE => 77 Avenue Southeast
# Cranston Road SE => Cranston Road Southeast
# 92 Avenue SE => 92 Avenue Southeast
# 53 Avenue SE => 53 Avenue Southeast
# 12 Avenue SE => 12 Avenue Southeast
# Canyon Meadows Drive SE => Canyon Meadows Drive Southeast
# 25 Street SE => 25 Street Southeast
# Lake Twintree Road SE => Lake Twintree Road Southeast
# 17A Street SE => 17A Street Southeast
# Cramond Green SE => Cramond Green Southeast
# Enterprise Way SE => Enterprise Way Southeast
# 112 Avenue SE => 112 Avenue Southeast
# Heritage Gate SE => Heritage Gate Southeast
# McKenzie Towne Square SE => McKenzie Towne Square Southeast
# Kingsland Way SE => Kingsland Way Southeast
# 61 Avenue SE => 61 Avenue Southeast
# 400 McKenzie Lake Bay SE => 400 McKenzie Lake Bay Southeast
# Providence Boulevard SE => Providence Boulevard Southeast
# Highfield Crescent SE => Highfield Crescent Southeast
# 10 Street SE => 10 Street Southeast
# 51 Street SE => 51 Street Southeast
# 4 Street SE => 4 Street Southeast
# 120 Avenue SE => 120 Avenue Southeast
# 34 Avenue SE => 34 Avenue Southeast
# 9 Street SE => 9 Street Southeast
# 78 Avenue SE => 78 Avenue Southeast
# 58 Avenue SE => 58 Avenue Southeast
# 12A Street SE => 12A Street Southeast
# Sunpark Plaza SE => Sunpark Plaza Southeast
# Technology Way SE => Technology Way Southeast
# Prestwick Drive SE => Prestwick Drive Southeast
# McKenzie Lake Way SE => McKenzie Lake Way Southeast
# 14 Street SE => 14 Street Southeast
# Auburn Bay Manor SE => Auburn Bay Manor Southeast
# 13 Street SE => 13 Street Southeast
# Parkview Way SE => Parkview Way Southeast
# Bellevue Avenue SE => Bellevue Avenue Southeast
# Cranwell Crescent SE => Cranwell Crescent Southeast
# Saddledome Rise SE => Saddledome Rise Southeast
# 42 Avenue SE => 42 Avenue Southeast
# Riverbrook Place SE => Riverbrook Place Southeast
# Douglasview Road SE => Douglasview Road Southeast
# Mahogany Park SE => Mahogany Park Southeast
# 21A Street SE => 21A Street Southeast
# 94 Avenue SE => 94 Avenue Southeast
# Ogden Crescent SE => Ogden Crescent Southeast
# 9 Avenue SE => 9 Avenue Southeast
# Diamond Drive SE => Diamond Drive Southeast
# 28 Street SE => 28 Street Southeast
# 4 Avenue SE => 4 Avenue Southeast
# 20 Avenue SE => 20 Avenue Southeast
# Arbour Crescent SE => Arbour Crescent Southeast
# Anderson Rd. SE => Anderson Rd. Southeast
# Promenade Way SE => Promenade Way Southeast
# 26 Avenue SE => 26 Avenue Southeast
# Lake Adams Crescent SE => Lake Adams Crescent Southeast
# Mapleglade Drive SE => Mapleglade Drive Southeast
# McKenzie Towne Avenue SE => McKenzie Towne Avenue Southeast
# McKenzie Towne Boulevard SE => McKenzie Towne Boulevard Southeast
# Seton Drive SE => Seton Drive Southeast
# 99 Avenue SE => 99 Avenue Southeast
# Chaparral Drive SE => Chaparral Drive Southeast
# Douglas Glen Boulevard SE => Douglas Glen Boulevard Southeast
# 46 Avenue SE => 46 Avenue Southeast
# 13 Avenue SE => 13 Avenue Southeast
# McKenzie Towne Villas SE => McKenzie Towne Villas Southeast
# Dartmouth Road SE => Dartmouth Road Southeast
# 34 Street SE => 34 Street Southeast
# 118 Avenue SE => 118 Avenue Southeast
# Penbrooke Drive SE => Penbrooke Drive Southeast
# Riverbrook Road SE => Riverbrook Road Southeast
# 18 Street SE => 18 Street Southeast
# Radcliffe Drive SE => Radcliffe Drive Southeast
# 15 St SE => 15 St Southeast
# Willingdon Boulevard SE => Willingdon Boulevard Southeast
# Ogden Dale Road SE => Ogden Dale Road Southeast
# 84 Avenue SE => 84 Avenue Southeast
# Parkland Way SE => Parkland Way Southeast
# 4216-54 Ave. SE => 4216-54 Ave. Southeast
# 62 Avenue SE => 62 Avenue Southeast
# Suncastle Drive SE => Suncastle Drive Southeast
# 84 Street SE => 84 Street Southeast
# Macleod Tr SE => Macleod Tr Southeast
# Mapleglen Crescent SE => Mapleglen Crescent Southeast
# 52 Avenue SE => 52 Avenue Southeast
# Parkland Boulevard SE => Parkland Boulevard Southeast
# 200 Auburn Bay Cove SE => 200 Auburn Bay Cove Southeast
# 80 Avenue SE => 80 Avenue Southeast
# 96 Avenue SE => 96 Avenue Southeast
# Lynnview Road SE => Lynnview Road Southeast
# Canyon Meadows Dr SE => Canyon Meadows Dr Southeast
# 79 Avenue SE => 79 Avenue Southeast
# Lake Twintree Way SE => Lake Twintree Way Southeast
# Queensland Drive SE => Queensland Drive Southeast
# 90 Ave SE => 90 Ave Southeast
# Macleod Trail SE => Macleod Trail Southeast
# 300 McKenzie Lake Bay SE => 300 McKenzie Lake Bay Southeast
# 39 Street SE => 39 Street Southeast
# Flint Road SE => Flint Road Southeast
# Anderson Road SE => Anderson Road Southeast
# 19 Avenue SE => 19 Avenue Southeast
# Lake Fraser Drive SE => Lake Fraser Drive Southeast
# Walden Gates SE => Walden Gates Southeast
# McKenzie Towne Dr SE => McKenzie Towne Dr Southeast
# Mount McKenzie Drive SE => Mount McKenzie Drive Southeast
# MacLeod Trail SE => MacLeod Trail Southeast
# Blackfoot Trail SE => Blackfoot Trail Southeast
# McKenzie Towne Drive SE => McKenzie Towne Drive Southeast
# Riverglen Drive SE => Riverglen Drive Southeast
# Prestwick Circle SE => Prestwick Circle Southeast
# Brightondale Park SE => Brightondale Park Southeast
# High Street SE => High Street Southeast
# Sunmount Green SE => Sunmount Green Southeast
# Cranston Rd SE => Cranston Rd Southeast
# Seton Way SE => Seton Way Southeast
# Auburn Bay Avenue SE => Auburn Bay Avenue Southeast
# Dover Ridge Drive SE => Dover Ridge Drive Southeast
# 5 Street SE => 5 Street Southeast
# Olympia Place SE => Olympia Place Southeast
# 40 Street SE => 40 Street Southeast
# Fairmount Drive SE => Fairmount Drive Southeast
# 100 McKenzie Lake Bay SE => 100 McKenzie Lake Bay Southeast
# 110 Avenue SE => 110 Avenue Southeast
# McKenzie Towne Manor SE => McKenzie Towne Manor Southeast
# Grandstand Trail SE => Grandstand Trail Southeast
# Willow Park Drive SE => Willow Park Drive Southeast
# Mapleridge Crescent SE => Mapleridge Crescent Southeast
# Railway Street SE => Railway Street Southeast
# Front Street SE => Front Street Southeast
# McKenzie Towne Gate SE => McKenzie Towne Gate Southeast
# 66 Street SE => 66 Street Southeast
# 35 Street SE => 35 Street Southeast
# MacDonald Avenue SE => MacDonald Avenue Southeast
# Lake Sylvan Dr. SE => Lake Sylvan Dr. Southeast
# Midpark Way SE => Midpark Way Southeast
# Spiller Road SE => Spiller Road Southeast
# Sunmills Drive SE => Sunmills Drive Southeast
# Maggie Street SE => Maggie Street Southeast
# Erin Park Drive SE => Erin Park Drive Southeast
# Walden Gate SE => Walden Gate Southeast
# 18 Avenue SE => 18 Avenue Southeast
# Olympic Way SE => Olympic Way Southeast
# High St SE => High St Southeast
# 39 Avenue SE => 39 Avenue Southeast
# 23 Avenue SE => 23 Avenue Southeast
# 58th Ave SE => 58th Ave Southeast
# Shawville Boulevard SE => Shawville Boulevard Southeast
# 30 Street SE => 30 Street Southeast
# 11 Avenue SE => 11 Avenue Southeast
# 52 Street SE => 52 Street Southeast
# Cranbrook Place SE => Cranbrook Place Southeast
# Sunmount Rise SE => Sunmount Rise Southeast
# Cranston Gate SE => Cranston Gate Southeast
# 32 Street SE => 32 Street Southeast
# Parkglen Place SE => Parkglen Place Southeast
# Quarry Park Boulevard SE => Quarry Park Boulevard Southeast
# 22 Street SE => 22 Street Southeast
# 46 Street SE => 46 Street Southeast
# 72 Avenue SE => 72 Avenue Southeast
# 41 Street SE => 41 Street Southeast
# 146 Avenue SE => 146 Avenue Southeast
# Venture Avenue SE => Venture Avenue Southeast
# Auburn Bay Lane SE => Auburn Bay Lane Southeast
# Sunbank Way SE => Sunbank Way Southeast
# Heritage Meadows Way SE => Heritage Meadows Way Southeast
# Lake Twintree Drive SE => Lake Twintree Drive Southeast
# Prestwick Avenue SE => Prestwick Avenue Southeast
# Sun Valley Drive SE => Sun Valley Drive Southeast
# 13A Street SE => 13A Street Southeast
# Maplecreek Drive SE => Maplecreek Drive Southeast
# Parkglen Crescent SE => Parkglen Crescent Southeast
# Riverbrook Court SE => Riverbrook Court Southeast
# Cranridge Terrace SE => Cranridge Terrace Southeast
# 58 Street SE => 58 Street Southeast
# 14 Avenue SE => 14 Avenue Southeast
# Heritage Drive SE => Heritage Drive Southeast
# Fyffe Road SE => Fyffe Road Southeast
# Barlow Trail SE => Barlow Trail Southeast
# Brightonstone Grove SE => Brightonstone Grove Southeast
# Dufferein Place SE => Dufferein Place Southeast
# Midlake Boulevard SE => Midlake Boulevard Southeast
# 8 Avenue SE => 8 Avenue Southeast
# Radisson Drive SE => Radisson Drive Southeast
# Fortalice Crescent SE => Fortalice Crescent Southeast
# 76 Avenue SE => 76 Avenue Southeast
# 9th Avenue SE => 9th Avenue Southeast
# 47 Street SE => 47 Street Southeast
# Sunmount Court SE => Sunmount Court Southeast
# 2 Street SE => 2 Street Southeast
# 19 Street SE => 19 Street Southeast
# 3 Avenue SE => 3 Avenue Southeast
# 69 Avenue SE => 69 Avenue Southeast
# 70 Avenue SE => 70 Avenue Southeast
# Shepard Place SE => Shepard Place Southeast
# Bow Bottom Trial SE => Bow Bottom Trial Southeast
# 31 Street SE => 31 Street Southeast
# 17 Avenue SE => 17 Avenue Southeast
# Riverbrook Way SE => Riverbrook Way Southeast
# 30th Street SE => 30th Street Southeast
# 90 Avenue SE => 90 Avenue Southeast
# 53 Street SE => 53 Street Southeast
# Copperstone Road SE => Copperstone Road Southeast
# Endeavor Drive SE => Endeavor Drive Southeast
# Cranberry Road SE => Cranberry Road Southeast
# Builders Road SE => Builders Road Southeast
# 15 Avenue SE => 15 Avenue Southeast
# 100 Street SE => 100 Street Southeast
# 26 Street SE => 26 Street Southeast
# 6 Street SE => 6 Street Southeast
# Center Street SE => Center Street Southeast
# Mount Douglas Close SE => Mount Douglas Close Southeast
# 12 Street SE => 12 Street Southeast
# Legacy Green SE => Legacy Green Southeast
# 106 Avenue SE => 106 Avenue Southeast
# 4A Avenue SE => 4A Avenue Southeast
# Ogden Road SE => Ogden Road Southeast
# Pensacola Way SE => Pensacola Way Southeast
# McIvor Boulevard SE => McIvor Boulevard Southeast
# 49 Avenue SE => 49 Avenue Southeast
# 700 McKenzie Lake Bay SE => 700 McKenzie Lake Bay Southeast
# Olympia Bay SE => Olympia Bay Southeast
# 56 Street SE => 56 Street Southeast
# 137 Avenue SE => 137 Avenue Southeast
# 94 Ave. SE => 94 Ave. Southeast
# Sunpark Drive SE => Sunpark Drive Southeast
# 94 Ave SE => 94 Ave Southeast
# 30 Avenue SE => 30 Avenue Southeast
# 54 Street SE => 54 Street Southeast
# Shawville Blvd. SE => Shawville Blvd. Southeast
# Bannister Road SE => Bannister Road Southeast
# Fisher Street SE => Fisher Street Southeast
# 48 Street SE => 48 Street Southeast
# 16 Street SE => 16 Street Southeast
# 66 Avenue SE => 66 Avenue Southeast
# 42 Street SE => 42 Street Southeast
# Mahogany Lane SE => Mahogany Lane Southeast
# Heritage Dr. SE => Heritage Dr. Southeast
# 600 McKenzie Lake Bay SE => 600 McKenzie Lake Bay Southeast
# Ramsay Street SE => Ramsay Street Southeast
# 73 Avenue SE => 73 Avenue Southeast
# Sun Park Plaza SE => Sun Park Plaza Southeast
# Auburn Meadows Boulevard SE => Auburn Meadows Boulevard Southeast
# 62 Street SE => 62 Street Southeast
# 23 AVE SE => 23 AVE Southeast
# Bow Bottom Trail SE => Bow Bottom Trail Southeast
# 6 Avenue SE => 6 Avenue Southeast
# Industry Way SE => Industry Way Southeast
# Maplecroft Road SE => Maplecroft Road Southeast
# 64 Avenue SE => 64 Avenue Southeast
# Douglasdale Boulevard SE => Douglasdale Boulevard Southeast
# Cranston Way SE => Cranston Way Southeast
# 21 Avenue SE => 21 Avenue Southeast
# Cranarch Rd SE => Cranarch Rd Southeast
# Auburn Bay Heights SE => Auburn Bay Heights Southeast
# 48 Avenue SE => 48 Avenue Southeast
# Lake Ontario Road SE => Lake Ontario Road Southeast
# Sun Valley Boulevard SE => Sun Valley Boulevard Southeast
# 36 Street SE => 36 Street Southeast
# Agate Crescent SE => Agate Crescent Southeast
# 15 Street SE => 15 Street Southeast
# 33 Street SE => 33 Street Southeast
# 83 Avenue SE => 83 Avenue Southeast
# Auburn Crest Way SE => Auburn Crest Way Southeast
# 68 Street SE => 68 Street Southeast
# 86 Avenue SE => 86 Avenue Southeast
# Dermot Baldwin Way SE => Dermot Baldwin Way Southeast
# 57 Street SE => 57 Street Southeast
# Deerpoint Road SE => Deerpoint Road Southeast
# Fairmount Dr. SE => Fairmount Dr. Southeast
# Sable Drive SE => Sable Drive Southeast
# Fisher Road SE => Fisher Road Southeast
# Forego Avenue SE => Forego Avenue Southeast
# Bonaventure Drive SE => Bonaventure Drive Southeast
# 29 Street SE => 29 Street Southeast
# 20A Street SE => 20A Street Southeast
# Lynnview Court SE => Lynnview Court Southeast
# Douglas Park Boulevard SE => Douglas Park Boulevard Southeast
# 24 Avenue SE => 24 Avenue Southeast
# 10 Avenue SE => 10 Avenue Southeast
# Watermark Villas => Watermark Villas

# %% [markdown]
# 整理电话格式

# %%
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

OSMFILE ="calgary_canada.osm"
a= re.compile(r'^[^+](\d.*){1,}')   #匹配不以“+”开头的电话号码

def audit_phone(invalid_phone,phone):
    
    if a.search(phone):
        invalid_phone.add(phone)

    

def is_phone(elem):
    return (elem.attrib['k']=="phone")




def audit(osmfile):
    osm_file = open(osmfile, "r")
    invalid_phone= set()
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "way" or elem.tag=="node":
            for tag in elem.iter("tag"):
                if is_phone(tag):
                    audit_phone(invalid_phone, tag.attrib['v'])
   
    osm_file.close()
                
                       
    return invalid_phone
     

b= re.compile(r'^[4|(](\d.*){1,}')   #匹配“4或（”开头的电话号码。
               
def update_phone(phone):
    if b.search(phone):
        phone="+1"+phone
        phone=phone.replace(".","")
        return phone
    else:
        return phone
   
    

if __name__ == '__main__':
    ph = audit(OSMFILE)
    print (ph)
    for phone in ph:
            better_phone = update_phone(phone)
            print phone, "=>", better_phone
# Out:
# set(['(403)286-8452', '(403) 270- 3780', '403 547-5020', '(403) 724-0123', '(403) 873-1015', '(403)932-5588', '(403) 781-6614', '4039788915', '(403) 278-0492', '403 288 6033', '888-381-2180', '(403) 290-0036', '(587) 747-8005', '(403) 662-8500', '(403) 282-5011', '(403)932-2455 ', '403-252-1800', '403-945-2437', '403-543-8188', '(403) 264-3366', '587-777-3378', '403-293-3900', '(403) 257-9700', '(403) 452-3565', '403-978-1520', '(403)291-9888', '(403) 287-6749', '(403)948-8804', '4035362480', '403-226-0010', '403-980-4670', '(587) 471-2480', '(403) 203-9299', '403-253-0101', '14032800880', '(403) 275-4444', '403-912-5115', '403-266-7062', '403-261-0931', '(403) 283-0654', '(403)240-3822', '(403) 474-7407', '(403) 249-7799', '403-246-7298', '(403) 235-2485', '403-202-8507', '403-245-5553 ext 15', '(403) 269-5581', '4032910323', '403 287 8008', '403-203-1789', '403-288-5444', '(587) 352-0452', '403 269 6551', '(403) 516-0347', '(587) 438-8838', '403-697-0868', '(403) 253-3367', '403 228 5553', '403.768.2600', '(403) 235-6634', '(403) 467-6719', '587-349-0355', '403-948-2169', '(403)735-1966', '403-509-2250', '14039100321', '403-974-4200', '(403) 310-4734', '(403) 532-3934', '(403) 255-5300', '403-301-3677', '(403) 274-8162', '(403) 695-7911', '403-720-1928', '(403) 723-0650', '(403)932-6355', '403-285-6226', '403-295-2222', '(403) 274-6106', '(403) 236-8833', '(403) 410-7694', '(403) 263-9604', '(403) 288-7299', '(403) 457-0697', '403 201 5519', '403-837-4023', '403-242-2050', '403-726-0466', '(403)948-4188', '403-282-1474', '(403) 282-0020', '(403) 720-0306', '403-244-2333', '(403) 455-4431', '(403) 374-0258', '403-276-6892', '403 287 1960', '4034503880', '888-749-4728', '403-453-1775', '4032500292', '(403)932-1410', '15874707878', '(403) 282-0555', '403-266-5223', '403-272-7460', '(403) 441-5402', '403-228-5925', '(403) 283-9900', '(403) 257-1766', '(403) 229-1001', '403-265-2885', '(403) 293-3549', '403-229-9155', '(403) 257-0672', '403 282 2804', '(403) 247-1102', '14034799118', '(403) 274-2114', '(403) 699-9843', '403-272-8206', '(403) 200-5437', '(403) 285-4527', '(403) 249-4565', '587-352-7307', '(403) 630-8835', '(403) 210-1932', '(403) 366-0687', '403 250-1133', '403.685.6801', '403-259-5555', '(403) 269-8811', '(403) 282-3588', '(403) 244-7279', '(403) 236-8022', '403) 287-3400', '587-433-9746', '403-253-7880', '403-225-1150', '4035148900', '(403) 693-0051', '403-242-8583', '(403) 270-7788', '4034549399', '403-242-2222', '(403) 247-2864', '(403) 221-6627', '587-350-7886', '403-279-8134', '587.897.0399', '(403) 861-2612', '403-948-9533', '(403) 568-5566', '(403) 287-6888'])
# (403)286-8452 => +1(403)286-8452
# (403) 270- 3780 => +1(403) 270- 3780
# 403 547-5020 => +1403 547-5020
# (403) 724-0123 => +1(403) 724-0123
# (403) 873-1015 => +1(403) 873-1015
# (403)932-5588 => +1(403)932-5588
# (403) 781-6614 => +1(403) 781-6614
# 4039788915 => +14039788915
# (403) 278-0492 => +1(403) 278-0492
# 403 288 6033 => +1403 288 6033
# 888-381-2180 => 888-381-2180
# (403) 290-0036 => +1(403) 290-0036
# (587) 747-8005 => +1(587) 747-8005
# (403) 662-8500 => +1(403) 662-8500
# (403) 282-5011 => +1(403) 282-5011
# (403)932-2455  => +1(403)932-2455
# 403-252-1800 => +1403-252-1800
# 403-945-2437 => +1403-945-2437
# 403-543-8188 => +1403-543-8188
# (403) 264-3366 => +1(403) 264-3366
# 587-777-3378 => 587-777-3378
# 403-293-3900 => +1403-293-3900
# (403) 257-9700 => +1(403) 257-9700
# (403) 452-3565 => +1(403) 452-3565
# 403-978-1520 => +1403-978-1520
# (403)291-9888 => +1(403)291-9888
# (403) 287-6749 => +1(403) 287-6749
# (403)948-8804 => +1(403)948-8804
# 4035362480 => +14035362480
# 403-226-0010 => +1403-226-0010
# 403-980-4670 => +1403-980-4670
# (587) 471-2480 => +1(587) 471-2480
# (403) 203-9299 => +1(403) 203-9299
# 403-253-0101 => +1403-253-0101
# 14032800880 => 14032800880
# (403) 275-4444 => +1(403) 275-4444
# 403-912-5115 => +1403-912-5115
# 403-266-7062 => +1403-266-7062
# 403-261-0931 => +1403-261-0931
# (403) 283-0654 => +1(403) 283-0654
# (403)240-3822 => +1(403)240-3822
# (403) 474-7407 => +1(403) 474-7407
# (403) 249-7799 => +1(403) 249-7799
# 403-246-7298 => +1403-246-7298
# (403) 235-2485 => +1(403) 235-2485
# 403-202-8507 => +1403-202-8507
# 403-245-5553 ext 15 => +1403-245-5553 ext 15
# (403) 269-5581 => +1(403) 269-5581
# 4032910323 => +14032910323
# 403 287 8008 => +1403 287 8008
# 403-203-1789 => +1403-203-1789
# 403-288-5444 => +1403-288-5444
# (587) 352-0452 => +1(587) 352-0452
# 403 269 6551 => +1403 269 6551
# (403) 516-0347 => +1(403) 516-0347
# (587) 438-8838 => +1(587) 438-8838
# 403-697-0868 => +1403-697-0868
# (403) 253-3367 => +1(403) 253-3367
# 403 228 5553 => +1403 228 5553
# 403.768.2600 => +14037682600
# (403) 235-6634 => +1(403) 235-6634
# (403) 467-6719 => +1(403) 467-6719
# 587-349-0355 => 587-349-0355
# 403-948-2169 => +1403-948-2169
# (403)735-1966 => +1(403)735-1966
# 403-509-2250 => +1403-509-2250
# 14039100321 => 14039100321
# 403-974-4200 => +1403-974-4200
# (403) 310-4734 => +1(403) 310-4734
# (403) 532-3934 => +1(403) 532-3934
# (403) 255-5300 => +1(403) 255-5300
# 403-301-3677 => +1403-301-3677
# (403) 274-8162 => +1(403) 274-8162
# (403) 695-7911 => +1(403) 695-7911
# 403-720-1928 => +1403-720-1928
# (403) 723-0650 => +1(403) 723-0650
# (403)932-6355 => +1(403)932-6355
# 403-285-6226 => +1403-285-6226
# 403-295-2222 => +1403-295-2222
# (403) 274-6106 => +1(403) 274-6106
# (403) 236-8833 => +1(403) 236-8833
# (403) 410-7694 => +1(403) 410-7694
# (403) 263-9604 => +1(403) 263-9604
# (403) 288-7299 => +1(403) 288-7299
# (403) 457-0697 => +1(403) 457-0697
# 403 201 5519 => +1403 201 5519
# 403-837-4023 => +1403-837-4023
# 403-242-2050 => +1403-242-2050
# 403-726-0466 => +1403-726-0466
# (403)948-4188 => +1(403)948-4188
# 403-282-1474 => +1403-282-1474
# (403) 282-0020 => +1(403) 282-0020
# (403) 720-0306 => +1(403) 720-0306
# 403-244-2333 => +1403-244-2333
# (403) 455-4431 => +1(403) 455-4431
# (403) 374-0258 => +1(403) 374-0258
# 403-276-6892 => +1403-276-6892
# 403 287 1960 => +1403 287 1960
# 4034503880 => +14034503880
# 888-749-4728 => 888-749-4728
# 403-453-1775 => +1403-453-1775
# 4032500292 => +14032500292
# (403)932-1410 => +1(403)932-1410
# 15874707878 => 15874707878
# (403) 282-0555 => +1(403) 282-0555
# 403-266-5223 => +1403-266-5223
# 403-272-7460 => +1403-272-7460
# (403) 441-5402 => +1(403) 441-5402
# 403-228-5925 => +1403-228-5925
# (403) 283-9900 => +1(403) 283-9900
# (403) 257-1766 => +1(403) 257-1766
# (403) 229-1001 => +1(403) 229-1001
# 403-265-2885 => +1403-265-2885
# (403) 293-3549 => +1(403) 293-3549
# 403-229-9155 => +1403-229-9155
# (403) 257-0672 => +1(403) 257-0672
# 403 282 2804 => +1403 282 2804
# (403) 247-1102 => +1(403) 247-1102
# 14034799118 => 14034799118
# (403) 274-2114 => +1(403) 274-2114
# (403) 699-9843 => +1(403) 699-9843
# 403-272-8206 => +1403-272-8206
# (403) 200-5437 => +1(403) 200-5437
# (403) 285-4527 => +1(403) 285-4527
# (403) 249-4565 => +1(403) 249-4565
# 587-352-7307 => 587-352-7307
# (403) 630-8835 => +1(403) 630-8835
# (403) 210-1932 => +1(403) 210-1932
# (403) 366-0687 => +1(403) 366-0687
# 403 250-1133 => +1403 250-1133
# 403.685.6801 => +14036856801
# 403-259-5555 => +1403-259-5555
# (403) 269-8811 => +1(403) 269-8811
# (403) 282-3588 => +1(403) 282-3588
# (403) 244-7279 => +1(403) 244-7279
# (403) 236-8022 => +1(403) 236-8022
# 403) 287-3400 => +1403) 287-3400
# 587-433-9746 => 587-433-9746
# 403-253-7880 => +1403-253-7880
# 403-225-1150 => +1403-225-1150
# 4035148900 => +14035148900
# (403) 693-0051 => +1(403) 693-0051
# 403-242-8583 => +1403-242-8583
# (403) 270-7788 => +1(403) 270-7788
# 4034549399 => +14034549399
# 403-242-2222 => +1403-242-2222
# (403) 247-2864 => +1(403) 247-2864
# (403) 221-6627 => +1(403) 221-6627
# 587-350-7886 => 587-350-7886
# 403-279-8134 => +1403-279-8134
# 587.897.0399 => 587.897.0399
# (403) 861-2612 => +1(403) 861-2612
# 403-948-9533 => +1403-948-9533
# (403) 568-5566 => +1(403) 568-5566
# (403) 287-6888 => +1(403) 287-6888

# %% [markdown]
# 整理邮编格式

# %%
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

OSMFILE ="calgary_canada.osm"
d=re.compile(r'([A-Z]\d){3}')   #匹配缺失空格的邮编。

def audit_zipcode(invalid_zipcodes,zipcode):
    
    if d.search(zipcode):
        invalid_zipcodes.add(zipcode)

    

def is_zipcode(elem):
    return (elem.attrib['k']=="addr:postcode")




def audit(osmfile):
    osm_file = open(osmfile, "r")
    invalid_zipcodes= set()
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "way" or elem.tag=="node":
            for tag in elem.iter("tag"):
                if is_zipcode(tag):
                    audit_zipcode(invalid_zipcodes, tag.attrib['v'])
   
    osm_file.close()
                
                       
    return invalid_zipcodes
     

                
def update_zip(zipcode):
    if d.search(zipcode):
        zipcode=zipcode[:3]+" "+zipcode[3:]
        return zipcode
    else:
        return zipcode
    
        
    
    

if __name__ == '__main__':
    invalid_zipcodes=audit(OSMFILE)
    print invalid_zipcodes
    for zipcode in invalid_zipcodes:
            better_zipcode= update_zip(zipcode)
            print zipcode, "=>", better_zipcode
# Out:
# set(['T2J1Y8', 'T2J1Y9', 'T2N3M4', 'T2N3M5', 'T2N3M2', 'T2N3M3', 'T2N3M6', 'T2N3M1', 'T2N0G4', 'T2N0G3', 'T3A0H7', 'T2N3M8', 'T2J1Y7', 'T2G4H6', 'T1X0K7', 'T3P0J9', 'T3S0B2', 'T2N3M7', 'T2V1P3', 'T2C2S4', 'T2C2S3', 'T3N0A6', 'T1Y6H2', 'T2M3W8', 'T2N3J9', 'T2G4K1', 'T2G4K2', 'T2C0H6', 'T2T0L4', 'T2L1H3', 'T2G0Y4', 'T2Z0H2', 'T3S0A2', 'T3G0C3', 'T3G4K4', 'T2P0W3', 'T3A1S4', 'T2E4N1', 'T2C5P1', 'T2N1X7', 'T2G2Z4', 'T2N2G3', 'T2N2G4', 'T2N2G9', 'T2J3M3', 'T2C2R6', 'T2X0A1', 'T3A2W6', 'T3A0Y9', 'T3A0Y8', 'T2W5J1', 'T2W5G1', 'T3J0G7', 'T3S0B9', 'T3A0Y5', 'T3A0Y7', 'T3A0Y6', 'T2N1G7', 'T2C4S9', 'T1X1L8', 'T2C4S6', 'T3A3B1', 'T2N1G8', 'T2X0W8', 'T2C5M4', 'T1Y6R7', 'T3A1R7', 'T3G2S9', 'T2Z0A9', 'T2C3W5', 'T2M4X6', 'T2M1Z7', 'T3S0A1', 'T2L1H4', 'T2J1X1', 'T1Y6J6', 'T3A5R8', 'T2G0B2', 'T2G0B1', 'T4C0Z8', 'T3R0A1', 'T3G4N1', 'T2X0T9', 'T2G4M4', 'T2Z0B1', 'T2C4Z6', 'T2J1V1', 'T2J1V3', 'T2J1V2', 'T2J1V5', 'T4C0S4', 'T3G4V9', 'T2N2E3', 'T2L2C3', 'T2Y0H5', 'T2Y0H4', 'T2N1V5', 'T2N1V3', 'T2Y5E2', 'T2C2X6', 'T3A0L6', 'T3A0L4', 'T3A0L3', 'T2C5K2', 'T3A0L1', 'T2N1E9', 'T2M2A1', 'T2C5L9', 'T2W5J2', 'T2C2T3', 'T2C4L7', 'T3J4L8', 'T4C0A4', 'T3A1A2', 'T3N0E4', 'T2Z0Z1', 'T3G5B3', 'T3A2Z1', 'T2M3W9', 'T2M4E6', 'T2V3H6', 'T2V3H8', 'T2V0E3', 'T3A0K2', 'T3G3K1', 'T3A0K7', 'T2N0B1', 'T2N0B2', 'T2N2B9', 'T1S1B1', 'T2N2B4', 'T2L1J4', 'T4C2B9', 'T2N2B1', 'T2C3C7', 'T2C5M1', 'T3A0K5', 'T3G3A3', 'T2N3H1', 'T2N3H3', 'T2N3H2', 'T2E4B1', 'T3E2J7', 'T2N3H7', 'T2N3H6', 'T2N2B6', 'T2J2T8', 'T0L0W0', 'T3A0K9', 'T3G2V1', 'T2V1K1', 'T3J1P6', 'T2N4S1', 'T3G2S2', 'T3A1W6', 'T3C1C9', 'T2N0K1', 'T3G4T3', 'T2V3K1', 'T2V3K2', 'T2N2C8', 'T2L2C4', 'T2N2C1', 'T3S0B8', 'T2N2C2', 'T2V2X3', 'T3A0N8', 'T2C5B7', 'T2C5B1', 'T3B3X3', 'T3A2X1', 'T1X0K3', 'T2N3G8', 'T2S0J2', 'T2E3J1', 'T3A1V5', 'T2C5N6', 'T2P3P8', 'T2C3B3', 'T3A2Y7', 'T3A2Y4', 'T3A2Y3', 'T2M2C2', 'T2N3H5', 'T2G0H7', 'T2N1Z5', 'T2C5K3', 'T2N1Z6', 'T2N3R3', 'T3A0K8', 'T2C4T6', 'T2X1M2', 'T2L1G1', 'T2N2A7', 'T2N2A6', 'T2N2A5', 'T2L0X9', 'T3S0B5', 'T3A4N4', 'T3A4N5', 'T3A4N6', 'T3C1E1', 'T2N2A9', 'T2N2A8', 'T2N3K4', 'T2N3K5', 'T2N3K6', 'T2N3K7', 'T2N3K1', 'T2N3K2', 'T2N3K3', 'T2Y5A3', 'T2Y5A2', 'T2Y5A4'])
# T2J1Y8 => T2J 1Y8
# T2J1Y9 => T2J 1Y9
# T2N3M4 => T2N 3M4
# T2N3M5 => T2N 3M5
# T2N3M2 => T2N 3M2
# T2N3M3 => T2N 3M3
# T2N3M6 => T2N 3M6
# T2N3M1 => T2N 3M1
# T2N0G4 => T2N 0G4
# T2N0G3 => T2N 0G3
# T3A0H7 => T3A 0H7
# T2N3M8 => T2N 3M8
# T2J1Y7 => T2J 1Y7
# T2G4H6 => T2G 4H6
# T1X0K7 => T1X 0K7
# T3P0J9 => T3P 0J9
# T3S0B2 => T3S 0B2
# T2N3M7 => T2N 3M7
# T2V1P3 => T2V 1P3
# T2C2S4 => T2C 2S4
# T2C2S3 => T2C 2S3
# T3N0A6 => T3N 0A6
# T1Y6H2 => T1Y 6H2
# T2M3W8 => T2M 3W8
# T2N3J9 => T2N 3J9
# T2G4K1 => T2G 4K1
# T2G4K2 => T2G 4K2
# T2C0H6 => T2C 0H6
# T2T0L4 => T2T 0L4
# T2L1H3 => T2L 1H3
# T2G0Y4 => T2G 0Y4
# T2Z0H2 => T2Z 0H2
# T3S0A2 => T3S 0A2
# T3G0C3 => T3G 0C3
# T3G4K4 => T3G 4K4
# T2P0W3 => T2P 0W3
# T3A1S4 => T3A 1S4
# T2E4N1 => T2E 4N1
# T2C5P1 => T2C 5P1
# T2N1X7 => T2N 1X7
# T2G2Z4 => T2G 2Z4
# T2N2G3 => T2N 2G3
# T2N2G4 => T2N 2G4
# T2N2G9 => T2N 2G9
# T2J3M3 => T2J 3M3
# T2C2R6 => T2C 2R6
# T2X0A1 => T2X 0A1
# T3A2W6 => T3A 2W6
# T3A0Y9 => T3A 0Y9
# T3A0Y8 => T3A 0Y8
# T2W5J1 => T2W 5J1
# T2W5G1 => T2W 5G1
# T3J0G7 => T3J 0G7
# T3S0B9 => T3S 0B9
# T3A0Y5 => T3A 0Y5
# T3A0Y7 => T3A 0Y7
# T3A0Y6 => T3A 0Y6
# T2N1G7 => T2N 1G7
# T2C4S9 => T2C 4S9
# T1X1L8 => T1X 1L8
# T2C4S6 => T2C 4S6
# T3A3B1 => T3A 3B1
# T2N1G8 => T2N 1G8
# T2X0W8 => T2X 0W8
# T2C5M4 => T2C 5M4
# T1Y6R7 => T1Y 6R7
# T3A1R7 => T3A 1R7
# T3G2S9 => T3G 2S9
# T2Z0A9 => T2Z 0A9
# T2C3W5 => T2C 3W5
# T2M4X6 => T2M 4X6
# T2M1Z7 => T2M 1Z7
# T3S0A1 => T3S 0A1
# T2L1H4 => T2L 1H4
# T2J1X1 => T2J 1X1
# T1Y6J6 => T1Y 6J6
# T3A5R8 => T3A 5R8
# T2G0B2 => T2G 0B2
# T2G0B1 => T2G 0B1
# T4C0Z8 => T4C 0Z8
# T3R0A1 => T3R 0A1
# T3G4N1 => T3G 4N1
# T2X0T9 => T2X 0T9
# T2G4M4 => T2G 4M4
# T2Z0B1 => T2Z 0B1
# T2C4Z6 => T2C 4Z6
# T2J1V1 => T2J 1V1
# T2J1V3 => T2J 1V3
# T2J1V2 => T2J 1V2
# T2J1V5 => T2J 1V5
# T4C0S4 => T4C 0S4
# T3G4V9 => T3G 4V9
# T2N2E3 => T2N 2E3
# T2L2C3 => T2L 2C3
# T2Y0H5 => T2Y 0H5
# T2Y0H4 => T2Y 0H4
# T2N1V5 => T2N 1V5
# T2N1V3 => T2N 1V3
# T2Y5E2 => T2Y 5E2
# T2C2X6 => T2C 2X6
# T3A0L6 => T3A 0L6
# T3A0L4 => T3A 0L4
# T3A0L3 => T3A 0L3
# T2C5K2 => T2C 5K2
# T3A0L1 => T3A 0L1
# T2N1E9 => T2N 1E9
# T2M2A1 => T2M 2A1
# T2C5L9 => T2C 5L9
# T2W5J2 => T2W 5J2
# T2C2T3 => T2C 2T3
# T2C4L7 => T2C 4L7
# T3J4L8 => T3J 4L8
# T4C0A4 => T4C 0A4
# T3A1A2 => T3A 1A2
# T3N0E4 => T3N 0E4
# T2Z0Z1 => T2Z 0Z1
# T3G5B3 => T3G 5B3
# T3A2Z1 => T3A 2Z1
# T2M3W9 => T2M 3W9
# T2M4E6 => T2M 4E6
# T2V3H6 => T2V 3H6
# T2V3H8 => T2V 3H8
# T2V0E3 => T2V 0E3
# T3A0K2 => T3A 0K2
# T3G3K1 => T3G 3K1
# T3A0K7 => T3A 0K7
# T2N0B1 => T2N 0B1
# T2N0B2 => T2N 0B2
# T2N2B9 => T2N 2B9
# T1S1B1 => T1S 1B1
# T2N2B4 => T2N 2B4
# T2L1J4 => T2L 1J4
# T4C2B9 => T4C 2B9
# T2N2B1 => T2N 2B1
# T2C3C7 => T2C 3C7
# T2C5M1 => T2C 5M1
# T3A0K5 => T3A 0K5
# T3G3A3 => T3G 3A3
# T2N3H1 => T2N 3H1
# T2N3H3 => T2N 3H3
# T2N3H2 => T2N 3H2
# T2E4B1 => T2E 4B1
# T3E2J7 => T3E 2J7
# T2N3H7 => T2N 3H7
# T2N3H6 => T2N 3H6
# T2N2B6 => T2N 2B6
# T2J2T8 => T2J 2T8
# T0L0W0 => T0L 0W0
# T3A0K9 => T3A 0K9
# T3G2V1 => T3G 2V1
# T2V1K1 => T2V 1K1
# T3J1P6 => T3J 1P6
# T2N4S1 => T2N 4S1
# T3G2S2 => T3G 2S2
# T3A1W6 => T3A 1W6
# T3C1C9 => T3C 1C9
# T2N0K1 => T2N 0K1
# T3G4T3 => T3G 4T3
# T2V3K1 => T2V 3K1
# T2V3K2 => T2V 3K2
# T2N2C8 => T2N 2C8
# T2L2C4 => T2L 2C4
# T2N2C1 => T2N 2C1
# T3S0B8 => T3S 0B8
# T2N2C2 => T2N 2C2
# T2V2X3 => T2V 2X3
# T3A0N8 => T3A 0N8
# T2C5B7 => T2C 5B7
# T2C5B1 => T2C 5B1
# T3B3X3 => T3B 3X3
# T3A2X1 => T3A 2X1
# T1X0K3 => T1X 0K3
# T2N3G8 => T2N 3G8
# T2S0J2 => T2S 0J2
# T2E3J1 => T2E 3J1
# T3A1V5 => T3A 1V5
# T2C5N6 => T2C 5N6
# T2P3P8 => T2P 3P8
# T2C3B3 => T2C 3B3
# T3A2Y7 => T3A 2Y7
# T3A2Y4 => T3A 2Y4
# T3A2Y3 => T3A 2Y3
# T2M2C2 => T2M 2C2
# T2N3H5 => T2N 3H5
# T2G0H7 => T2G 0H7
# T2N1Z5 => T2N 1Z5
# T2C5K3 => T2C 5K3
# T2N1Z6 => T2N 1Z6
# T2N3R3 => T2N 3R3
# T3A0K8 => T3A 0K8
# T2C4T6 => T2C 4T6
# T2X1M2 => T2X 1M2
# T2L1G1 => T2L 1G1
# T2N2A7 => T2N 2A7
# T2N2A6 => T2N 2A6
# T2N2A5 => T2N 2A5
# T2L0X9 => T2L 0X9
# T3S0B5 => T3S 0B5
# T3A4N4 => T3A 4N4
# T3A4N5 => T3A 4N5
# T3A4N6 => T3A 4N6
# T3C1E1 => T3C 1E1
# T2N2A9 => T2N 2A9
# T2N2A8 => T2N 2A8
# T2N3K4 => T2N 3K4
# T2N3K5 => T2N 3K5
# T2N3K6 => T2N 3K6
# T2N3K7 => T2N 3K7
# T2N3K1 => T2N 3K1
# T2N3K2 => T2N 3K2
# T2N3K3 => T2N 3K3
# T2Y5A3 => T2Y 5A3
# T2Y5A2 => T2Y 5A2
# T2Y5A4 => T2Y 5A4

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-



import csv
import codecs
import pprint
import re
import xml.etree.cElementTree as ET

#import cerberus

import schema

OSM_PATH = "calgary_canada.osm"

NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

SCHEMA = schema.schema

# Make sure the fields order in the csvs matches the column order in the sql table schema
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']



def clean_tag(tag):
    if tag.attrib['k']=="addr:street":
        tag.attrib['v']=update_name(tag.attrib['v'],mapping)
    elif tag.attrib['k']=="phone":
        tag.attrib['v']=update_phone(tag.attrib['v'])
    elif tag.attrib['k']=="addr:postcode":
        tag.attrib['v']=update_zip(tag.attrib['v'])
    return tag
        
        
def shape_tag(el,tag):
    tag_cleaned = clean_tag(tag)   #调用清洗好数据的函数
    tag_dict={
        'id':el.attrib['id'],
        'key':tag_cleaned.attrib['k'],       #调用清洗好的数据
        'value':tag_cleaned.attrib['v'],
        'type':'regular'
        }
    if LOWER_COLON.match(tag_dict['key']):
        tag_dict['type'],_,tag_dict['key']=tag_dict['key'].partition(':')
    return tag_dict
    
def shape_way_node(el,i,nd):
    return{
        'id':el.attrib['id'],
        'node_id':nd.attrib['ref'],
        'position':i
    }
    

def shape_element(el, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
#     tags = []  # Handle secondary tags the same way for both node and way elements

   
  
    tags=[shape_tag(el,t) for t in el.iter('tag')]    #从中取出“tag”的内容，把它命名为t。调用shape_tag函数。
    if el.tag == 'node':
        node_attribs={f:el.attrib[f] for f in node_attr_fields}
        return {'node': node_attribs, 'node_tags': tags}
    elif el.tag == 'way':
        way_attribs={f:el.attrib[f] for f in way_attr_fields}
        
        way_nodes=[shape_way_node (el,i,nd)
                  for i,nd in enumerate(el.iter('nd'))]
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}


# ================================================== #
#               Helper Functions                     #
# ================================================== #
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


#def validate_element(element, validator, schema=SCHEMA):
    #  """Raise ValidationError if element does not match schema"""
    #if validator.validate(element, schema) is not True:
       # field, errors = next(validator.errors.iteritems())
       # message_string = "\nElement of type '{0}' has the following errors:\n{1}"
       # error_string = pprint.pformat(errors)
        
       # raise Exception(message_string.format(field, error_string))


class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)


# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'wb') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'wb') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'wb') as ways_file, \
        codecs.open(WAY_NODES_PATH, 'wb') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'wb') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

      #  validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
           # if el:
              #  if validate is True:
                   # validate_element(el, validator)

            if element.tag == 'node':
                nodes_writer.writerow(el['node'])
                node_tags_writer.writerows(el['node_tags'])
            elif element.tag == 'way':
                ways_writer.writerow(el['way'])
                way_nodes_writer.writerows(el['way_nodes'])
                way_tags_writer.writerows(el['way_tags'])


if __name__ == '__main__':
    # Note: Validation is ~ 10X slower. For the project consider using a small
    # sample of the map when validating.
    process_map(OSM_PATH, validate=True)
